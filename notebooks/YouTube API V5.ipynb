# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow, Flow
from google.auth.transport.requests import Request
from google.auth.exceptions import RefreshError
import json
from google.oauth2.credentials import Credentials
import os
from pathlib import Path
from elasticsearch import Elasticsearch
import json
import pandas as pd

# %%
class YouTubeAPIOauthConstants:
    TOKEN_FILE = 'credentials.json'
    API_SERVICE_NAME = 'youtube'
    API_VERSION = 'v3'
    SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

# %%
class YouTubeAPIAuth:
    __TOKEN_FILE = YouTubeAPIOauthConstants.TOKEN_FILE
    __API_SERVICE_NAME = YouTubeAPIOauthConstants.API_SERVICE_NAME
    __API_VERSION = YouTubeAPIOauthConstants.API_VERSION
    __SCOPES = YouTubeAPIOauthConstants.SCOPES
    
    def __init__(self):
        self.__credentials_path = None
        self.__client_secrets_file = None
        self.__credentials = None
    
    def authenticate_from_client_secrets_file(self, client_secrets_file: str, 
                                              credentials_path: str = ''):
        self.__verify_client_secret_file(client_secrets_file)
        self.__client_secrets_file = client_secrets_file
        if not credentials_path or not os.path.exists(credentials_path):
            self.__credentials_path = self.__get_default_credentials_path()
        else:
            self.__credentials_path = credentials_path
        return self.__from_client_secrets_file()
    
    def authenticate_from_credentials(self, credentials_path: str):
        if not credentials_path:
            raise ValueError('The credentials file path has to be provided.')
        if not isinstance(credentials_path, str):
            raise TypeError('The credentials file should be a string.')
        if not os.path.exists(credentials_path):
            raise ValueError('The credentials file path has to exist!')
        if not Path(credentials_path).is_file():
            raise ValueError('The credentials path must be a file.')
        with open(credentials_path, "r") as credentials:
            self.__credentials = Credentials(**json.load(credentials))
        return self.__from_credentials()
            
    
    def __verify_client_secret_file(self, client_secrets_file: str) -> None:
        """Verfy the client secret file."""
        if not client_secrets_file:
            raise ValueError('The clients secret file path has to be provided.')
        if not isinstance(client_secrets_file, str):
            raise TypeError('The clients secret file should be a string.')
        if not os.path.exists(client_secrets_file):
            raise ValueError(f'The path {client_secrets_file} does not exist!')
            
    def __get_default_credentials_path(self):
        """Generate the default api token file location."""
        current_user_home_dir = os.path.expanduser('~')
        credentials_path = os.path.join(current_user_home_dir, self.__TOKEN_FILE)
        return credentials_path
    
    def __from_client_secrets_file(self):
        if os.path.exists(self.__credentials_path):
            with open(self.__credentials_path, "r") as credentials:
                self.__credentials = Credentials(**json.load(credentials))
        if not self.__credentials or not self.__credentials.valid:
            if self.__credentials and self.__credentials.expired and self.__credentials.refresh_token:
                self.__credentials.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(self.__client_secrets_file, self.__SCOPES)
                self.__credentials = flow.run_local_server(port=0)
            with open(self.__credentials_path, "w") as credentials_path:
                credentials = self.__credentials_to_dict(self.__credentials)
                json.dump(credentials, credentials_path)
        youtube_api_client = build(self.__API_SERVICE_NAME, self.__API_VERSION, 
                                   credentials=self.__credentials)
        return youtube_api_client
    
    def __from_credentials(self):
        if not self.__credentials or not self.__credentials.valid:
            if self.__credentials and self.__credentials.expired and self.__credentials.refresh_token:
                self.__credentials.refresh(Request())
            with open(self.__credentials_path, "w") as credentials_path:
                credentials = self.__credentials_to_dict(self.__credentials)
                json.dump(credentials, credentials_path)
        youtube_api_client = build(self.__API_SERVICE_NAME, self.__API_VERSION, 
                                   credentials=self.__credentials)
        return youtube_api_client
    
    def generate_credentials(self, client_secrets_file: str, credentials_path: str = ''):
        self.__verify_client_secret_file(client_secrets_file)
        self.__client_secrets_file = client_secrets_file
        if not credentials_path or not os.path.exists(credentials_path):
            self.__credentials_path = self.__get_default_credentials_path()
        else:
            self.__credentials_path = credentials_path
        flow = Flow.from_client_secrets_file(
            self.__client_secrets_file,
            scopes=self.__SCOPES,
            redirect_uri='urn:ietf:wg:oauth:2.0:oob')
        auth_url, _ = flow.authorization_url(prompt='consent')

        print('Please go to this URL: {}'.format(auth_url))
        code = input('Enter the authorization code: ')
        flow.fetch_token(code=code)
        self.__credentials = flow.credentials
        credentials_dict = self.__credentials_to_dict(self.__credentials)
        with open(self.__credentials_path, "w") as credentials_path:
            json.dump(credentials_dict, credentials_path)
    
    def __credentials_to_dict(self, credentials: Credentials) -> dict:
        """Convert credentials to a dict for easy work with Flask."""
        return dict(
            token=credentials.token,
            refresh_token=credentials.refresh_token,
            token_uri=credentials.token_uri,
            client_id=credentials.client_id,
            client_secret=credentials.client_secret,
            scopes=credentials.scopes
        )

# %%
class YouTubeSearchQuery:
    """A query to pass to the search resource."""
    
    def __init__(self, query_string: str):
        self.__query_string = query_string
        
    @property
    def query_string(self):
        return self.__query_string
    
    @query_string.setter
    def query_string(self, query_str: str):
        if not query_str:
            raise ValueError('The query string has to be provided')
        if not isinstance(query_str, str):
            raise TypeError('The query string has to be a string')
        self.__query_string = query_str

# %%
class YouTubeVideoSearchQuery(YouTubeSearchQuery):
    pass

# %%
class YouTubeSearchType:
    VIDEO = 'video'
    CHANNEL = 'channel'
    PLAYLIST = 'playlist'

# %%
class YouTubeSearch:
    __MAX_RESULTS = 10
    __REGION_CODE = 'US'
    
    def __init__(self, *args, **kwargs):
        pass

# %%
class VideoStat:
    def __init__(self, stat: int):
        self.__stat = stat
     
   #stat setter 
    def stat(self):
        pass
    
    #stat getter
    def get_stat():
        pass
    
    def __format_stat(self):
        pass

# %%
class YouTubeVideoStats:
    def __init__(self, viewCount: int, likeCount: int, commentCount: int):
        self.__view_count = int(viewCount)
        self.__like_count = int(likeCount)
        self.__comment_count = int(commentCount)
        
    def get_video_stats(self):
        video_stats = {
            'view_count': self.__view_count,
            'like_count': self.__like_count,
            'comment_count': self.__comment_count
        }
        return video_stats

# %%
class YouTubeVideoDetails:
    def __init__(self, id: str, channelId: str, title: str, channelTitle: str, 
                 description: str, thumbnails: str, tags: list[str], duration: str, licensedContent: bool):
        self.__id = id
        self.__channel_id = channelId
        self.__title = title
        self.__channel_title = channelTitle
        self.__description = description
        self.__thumbnails = thumbnails
        self.__tags = tags
        self.__duration = duration
        self.__licensed_content = licensedContent
        
    def get_video_details(self):
        video_details = {
            'id': self.__id,
            'channel_id': self.__channel_id,
            'title': self.__title,
            'channel_title': self.__channel_title,
            'description': self.__description,
            'thumbnail': self.get_video_thumbnail(),
            'tags': self.__tags,
            'duration': self.__duration,
            'licensed_content': self.__licensed_content
        }
        return video_details
    
    def get_video_thumbnail(self):
        thumbnail = ''
        if self.__thumbnails:
            if self.__thumbnails.get('default'):
                thumbnail = self.__thumbnails.get('default').get('url')
            elif self.__thumbnails.get('medium'):
                thumbnail = self.__thumbnails.get('medium').get('url')
            elif self.__thumbnails.get('high'):
                thumbnail = self.__thumbnails.get('high').get('url')
            elif self.__thumbnails.get('standard'):
                thumbnail = self.__thumbnails.get('standard').get('url')
            elif self.__thumbnails.get('maxres'):
                thumbnail = self.__thumbnails.get('maxres').get('url')
        return thumbnail
    
    def get_video_title(self):
        return self.__title
    
    def get_video_id(self):
        return self.__id
    
    def get_video_description(self):
        return self.__description
    
    def get_video_duration(self):
        pass
    
    def get_video_tags(self):
        if self.__tags:
            return self.__tags
        return []
    
    def get_channel_id(self):
        return self.__channel_id
    
    def get_channel_title(self):
        return self.__channel_title

# %%
class YouTubeComment:
    def __init__(self, id: str, videoId: str, totalReplyCount: str, textDisplay: str, 
                authorDisplayName: str, authorProfileImageUrl: str, authorChannelId: str,
                likeCount: str, publishedAt: str, updatedAt: str):
        self.__id = id
        self.__video_id = videoId
        self.__total_reply_count = totalReplyCount
        self.__text_display = textDisplay
        self.__author_display_name = authorDisplayName
        self.__author_profile_image_url = authorProfileImageUrl
        self.__author_channel_id = authorChannelId
        self.__like_count = int(likeCount)
        self.__published_at = publishedAt
        self.__updated_at = updatedAt
        
    def get_comment(self):
        comment = dict(
            id=self.__id,
            videoId=self.__video_id,
            totalReplyCount=self.__total_reply_count,
            textDisplay=self.__text_display,
            authorDisplayName = self.__author_display_name,
            authorProfileImageUrl = self.__author_profile_image_url,
            authorChannelId = self.__author_channel_id,
            likeCount = self.__like_count,
            publishedAt = self.__published_at,
            updatedAt = self.__updated_at
        )
        return comment
    
    def get_comment_text(self):
        comment_text = self.__text_display
        return comment_text
    
    def __str__(self):
        return self.get_comment_text()
    
    def __repr__(self):
        return f"YouTubeComment(id='{self.__id}', videoId='{self.__video_id}', \
        totalReplyCount={self.__total_reply_count})"

# %%
class YouTubeCommentThread:
    def __init__(self, video_id: str):
        self.__video_id = video_id
        
    def get_video_comments(self, youtube_client):
        """Get the top level comments for a video."""
        youtube_comments = self.__find_comments(youtube_client)
        youtube_comments = [self.__create_comment(comment) for comment in youtube_comments]
        return youtube_comments
        
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            videoId=self.__video_id,
            part='snippet,replies'
        ) 
        return basic_info_params
    
    def __find_comments(self, youtube_client):
        """Find the video comments."""
        basic_info_params = self.__generate_basic_info_params()
        search_request = youtube_client.commentThreads().list(
                **basic_info_params
            )
        search_response = search_request.execute()
        comments = self.__parse_comments(search_response)
        return comments
    
    def __create_comment(self, comment_details):
        youtube_comment = YouTubeComment(**comment_details)
        return youtube_comment

    def __parse_comments(self, search_response):
        items = search_response['items']
        comments = []
        for item in items:
            comments.append({
                'id': item['id'],
                'videoId': item['snippet']['videoId'],
                'totalReplyCount': item['snippet']['totalReplyCount'],
                'textDisplay': item['snippet']['topLevelComment']['snippet']['textDisplay'],
                'authorDisplayName': item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                'authorProfileImageUrl': item['snippet']['topLevelComment']['snippet']['authorProfileImageUrl'],
                'authorChannelId': item['snippet']['topLevelComment']['snippet']['authorChannelId']['value'],
                'likeCount': item['snippet']['topLevelComment']['snippet']['likeCount'],
                'publishedAt': item['snippet']['topLevelComment']['snippet']['publishedAt'],
                'updatedAt': item['snippet']['topLevelComment']['snippet']['updatedAt']
        })
        return comments

# %%
class YouTubeVideo:
    """A YouTube Video."""
    def __init__(self, video_details, youtube_client):
        self.__youtube_client = youtube_client
        self.__video_stats = self.__create_video_stats(video_details)
        self.__video_details = self.__create_video_details(video_details)
        self.__video_top_level_comments = self.__set_video_comments()
        self.__channel = self.__set_video_channel()
        
    def set_youtube_client(self, youtube_client):
        self.__youtube_client = youtube_client
        
    def get_video_stats_details(self):
        video_stats_details = dict()
        video_stats_details['details'] = self.get_video_details()
        video_stats_details['statistics'] = self.get_video_stats()
        return video_stats_details
    
    def __set_video_comments(self):
        youtube_commenthread = YouTubeCommentThread(self.get_video_id())
        video_top_level_comments = youtube_commenthread.get_video_comments(self.__youtube_client)
        return video_top_level_comments
    
    def __set_video_channel(self):
        find_channel = FindChannel(self.__youtube_client)
        video_channel = find_channel.find_channel_by_id(self.get_channel_id())
        return video_channel
    
    def get_video_comments(self):
        if not self.__video_top_level_comments:
            self.__set_video_comments()
        return self.__video_top_level_comments
    
    def get_video_channel(self):
        if not self.__channel:
            self.__set_video_channel()
        return self.__channel
        
    def __create_video_stats(self, video_details: dict):
        video_stats = YouTubeVideoStats(**video_details['statistics'])
        return video_stats
    
    def __create_video_details(self, video_details: dict):
        video_details = YouTubeVideoDetails(**video_details['details'])
        return video_details
        
    def get_video_stats(self):
        return self.__video_stats.get_video_stats()
    
    def get_video_details(self):
        return self.__video_details.get_video_details()
    
    def get_video_id(self):
        return self.__video_details.get_video_id()
    
    def get_video_title(self):
        return self.__video_details.get_video_title()
    
    def get_video_description(self):
        return self.__video_details.get_video_description()
    
    def get_video_tags(self):
        return self.__video_details.get_video_tags()
    
    def get_channel_id(self):
        return self.__video_details.get_channel_id()
    
    def get_channel_title(self):
        return self.__video_details.get_channel_title()
    
    def get_video_thumbnail(self):
        return self.__video_details.get_video_thumbnail()
    
    def get_video_channel_thumbnail(self):
        if not self.__channel:
            self.__set_video_channel()
        return self.__channel.get_channel_thumbnail()
    
    def to_dict(self):
        return {
            'video_id': self.get_video_id(),
            'video_title': self.get_video_title(),
            'video_description': self.get_video_description(),
            'video_thumbnail': self.get_video_thumbnail(),
            'video_tags': self.get_video_tags(),
            'channel_id': self.get_channel_id(),
            'channel_title': self.get_channel_title(),
            'channel_thumbnail': self.get_video_channel_thumbnail()
        }
    
    def to_csv(self):
        pass
    
    def __str__(self):
        return f'{self.get_video_title()} from {self.get_channel_title()}'
    
    def __repr__(self) -> str:
        return f"YouTubeVideo(id={self.get_video_id()}, video_title={self.get_video_title()})"

# %%
class YouTubeVideoCollection:
    def __init__(self):
        self.__youtube_videos = []
        self.__es_client = None
        
    def get_youtube_videos(self):
        return self.__youtube_videos
    
    def add_video(self, video: YouTubeVideo):
        self.__youtube_videos.append(video)
        
    def add_videos(self, videos: list[YouTubeVideo]):
        for video in videos:
            self.__youtube_videos.append(video)
    
    def save_to_database(self):
        pass
    
    def save_to_elasticsearch(self, index_name, elastic_search_host):
        if not self.__es_client:
            self.__create_es_client(elastic_search_host)
        for video in self.__youtube_videos:
            video_details = video.to_dict()
            self.__es_client.index(index=index_name, document=video_details, id=video_details['video_id'])
        
    def __delete_index(self, index_name):
        self.__es_client.indices.delete(index=index_name, ignore=[400, 404])
        
    def __create_index(self, index_name):
        self.__es_client.indices.create(index = index_name)
    
    def __create_es_client(self, es_host):
        if not self.__es_client:
            self.__es_client = Elasticsearch(hosts=[es_host])
    
    def save_to_csv(self):
        pass
    
    def save_to_json(self, file=''):
        if not file:
            file = 'file.json'
        with open(file, 'w') as file_path:
            videos = [video.to_dict() for video in self.__youtube_videos]
            json.dump(videos)
    
    def to_pandas(self):
        videos = [video.to_dict() for video in self.__youtube_videos]
        video_ids = []
        video_titles = []
        video_descriptions = []
        video_thumbnails = []
        video_tags = []
        channel_ids = []
        channel_titles = []
        for video in videos:
            video_ids.append(video['video_id'])
            video_titles.append(video['video_title'])
            video_descriptions.append(video['video_description'])
            video_thumbnails.append(video['video_thumbnail'])
            video_tags.append(video['video_tags'])
            channel_ids.append(video['channel_id'])
            channel_titles.append(video['channel_title'])
        data = {
            'video_id': video_ids,
            'video_title': video_titles,
            'video_description': video_descriptions,
            'video_thumbnail': video_thumbnails,
            'video_tags': video_tags,
            'channel_id': channel_ids,
            'channel_title': channel_titles
        }

        df = pd.DataFrame(data)

# %%
class FindVideo:
    def __init__(self, youtube_client):
        """Find the video with the given id."""
        self.__youtube_client = youtube_client
        
    def __generate_basic_info_params(self, video_id: str):
        basic_info_params = dict(
            id=video_id,
            part='snippet,contentDetails,statistics'
        ) 
        return basic_info_params
    
    def find_video(self, video_id: str):
        """Find the video."""
        basic_info_params = self.__generate_basic_info_params(video_id)
        search_request = self.__youtube_client.videos().list(
                **basic_info_params
            )
        search_response = search_request.execute()
        parsed_response = self.__parse_video_details(search_response)
        youtube_video = YouTubeVideo(parsed_response, self.__youtube_client)
        return youtube_video
    
    def __parse_video_details(self, video_details: dict):
        """Parse the video details.

        Returns
        -------
        parsed_video_details: dict
            A dictionary of the YouTube video details.
        """
        parsed_video_details = dict()
        items = video_details['items'][0]
        parsed_video_details['details'] = dict()
        parsed_video_details['statistics'] = dict()
        parsed_video_details['details']['id'] = items['id']
        parsed_video_details['details']['channelId'] = items['snippet']['channelId']
        parsed_video_details['details']['title'] = items['snippet']['title']
        parsed_video_details['details']['channelTitle'] = items['snippet']['channelTitle']
        parsed_video_details['details']['description'] = items['snippet']['description']
        parsed_video_details['details']['thumbnails'] = items['snippet']['thumbnails']
        if items['snippet'].get('tags'):
            parsed_video_details['details']['tags'] = items['snippet']['tags']
        else:
            parsed_video_details['details']['tags'] = []
        parsed_video_details['details']['duration'] = items['contentDetails']['duration']
        parsed_video_details['details']['licensedContent'] = items['contentDetails']['licensedContent']
        parsed_video_details['statistics']['viewCount'] = items['statistics']['viewCount']
        parsed_video_details['statistics']['likeCount'] = items['statistics']['likeCount']
        parsed_video_details['statistics']['commentCount'] = items['statistics']['commentCount']
        return parsed_video_details

# %%
class VideoSearch(YouTubeSearch):
    __MAX_RESULTS = 10
    __REGION_CODE = 'US'
    
    def __init__(self, youtube_client):
        self.__youtube_client = youtube_client
        self.__type = YouTubeSearchType.VIDEO
        self.__query = ''
        self.__videos = YouTubeVideoCollection()
        
    def __get_query(self):
        return self.__query.query_string
    
    def get_videos(self):
        return self.__videos
        
    def basic_info(self):
        basic_info_params = self.__generate_basic_info_params()
        return basic_info_params
    
    def advanced_info(self):
        pass
    
    def all_info(self):
        pass
    
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            part='id',
            type=self.__type,
            q=self.__get_query(),
            maxResults=self.__MAX_RESULTS,
            regionCode=self.__REGION_CODE
        ) 
        return basic_info_params
    
    def __generate_basic_info_params_for_related_video(self, video_id):
        basic_info_params = dict(
            part='id',
            type=self.__type,
            relatedToVideoId=video_id,
            maxResults=self.__MAX_RESULTS,
            regionCode=self.__REGION_CODE
        ) 
        return basic_info_params
    
    def __generate_basic_info_params_for_most_popular_video_by_region(self, 
                region_code):
        basic_info_params = dict(
            part='id',
            chart='mostPopular',
            regionCode=region_code
        ) 
        return basic_info_params
    
    def __generate_basic_info_params_for_most_popular_video_by_category(self, 
                category_id):
        basic_info_params = dict(
            part='id',
            chart='mostPopular',
            videoCategoryId=category_id
        ) 
        return basic_info_params
    
    def search_videos(self, query_string: str, next_page_token=None):
        self.__query = YouTubeSearchQuery(query_string)
        basic_info_params = self.__generate_basic_info_params()
        if next_page_token:
            basic_info_params['pageToken'] = next_page_token
        search_request = self.__youtube_client.search().list(
            **basic_info_params
        )
        search_response = search_request.execute()
        (previous_page_token, next_page_token, videos) = self.__parse_basic_response(search_response)
        return (previous_page_token, next_page_token, videos)
    
    def __parse_basic_response(self, search_response):
        videos = []
        previous_page_token = search_response.get('prevPageToken', '')
        next_page_token = search_response.get('nextPageToken', '')
        video_results = search_response['items']
        for video_result in video_results:
            video_id = video_result['id']['videoId']
            youtube_video = FindVideo(self.__youtube_client).find_video(video_id)
            videos.append(youtube_video)
        self.__videos.add_videos(videos)
        return (previous_page_token, next_page_token, videos)
    
    def __parse_basic_response_popular_videos(self, search_response):
        videos = []
        video_results = search_response['items']
        for video_result in video_results:
            if video_result.get('id'):
                video_id = video_result['id']
            else:
                video_id = video_result['id']['videoId']
            youtube_video = FindVideo(self.__youtube_client).find_video(video_id)
            videos.append(youtube_video)
        return videos
    
    def search_related_videos(self, youtube_video):
        basic_info_params = self.__generate_basic_info_params_for_related_video(youtube_video.get_video_id())
        search_request = self.__youtube_client.search().list(
            **basic_info_params
        )
        search_response = search_request.execute()
        (previous_page_token, next_page_token, videos) = self.__parse_basic_response(search_response)
        return (previous_page_token, next_page_token, videos)
    
    def search_most_popular_videos_by_region(self, region_code, youtube_client, search_type='basic'):
        search_response = None
        if search_type == 'basic':
            basic_info_params = self.__generate_basic_info_params_for_most_popular_video_by_region(region_code)
            search_request = youtube_client.videos().list(
                **basic_info_params
            )
            search_response = search_request.execute()
            videos = self.__parse_basic_response_popular_videos(search_response, youtube_client)
        return videos
    
    def search_most_popular_videos_by_category(self, category_id, youtube_client, search_type='basic'):
        search_response = None
        if search_type == 'basic':
            basic_info_params = self.__generate_basic_info_params_for_most_popular_video_by_category(category_id)
            search_request = youtube_client.videos().list(
                **basic_info_params
            )
            try:
                search_response = search_request.execute()
                videos = self.__parse_basic_response_popular_videos(search_response, youtube_client)
            except:
                videos = []
        return videos

# %%
class YouTubeVideoCategory:
    def __init__(self, id, title):
        self.__id = id
        self.__title = title
        
    def get_id(self):
        return self.__id
    
    def get_title(self):
        return self.__title
    
    def __str__(self):
        return self.get_title()
    
    def __repr__(self):
        return f"YouTubeVideoCategory(id='{self.__id}', title='{self.__title}')"

# %%
class SearchYouTubeVideoCategories:
    def __init__(self, youtube_client, region_code='us'):
        self.__youtube_client = youtube_client
        self.__region_code = region_code
        self.__youtube_video_categories = self.__search_video_categories()
    
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            part='snippet',
            regionCode=self.__region_code
        )
        return basic_info_params
    
    def __search_video_categories(self):
        basic_info_params = self.__generate_basic_info_params()
        search_request = self.__youtube_client.videoCategories().list(
                **basic_info_params
            )
        search_response = search_request.execute()
        video_categories = self.__parse_categories(search_response)
        return video_categories
    
    def __parse_categories(self, search_response):
        category_data = []
        items = search_response['items']
        for item in items:
            category = dict()
            category['id'] = item['id']
            category['title'] = item['snippet']['title']
            category_data.append(YouTubeVideoCategory(**category))
        return category_data
    
    def get_youtube_video_categories(self):
        return self.__youtube_video_categories

# %%
class PlaylistItem:
    def __init__(self, id, publishedAt, channelId, title, description, thumbnails, 
                channelTitle, position, videoId, videoOwnerChannelTitle, 
                videoOwnerChannelId):
        self.__id = id
        self.__publishedAt = publishedAt
        self.__channelId = channelId
        self.__title = title
        self.__description = description
        self.__thumbnails = thumbnails
        self.__channelTitle = channelTitle
        self.__position = int(position)
        self.__videoId = videoId
        self.__videoOwnerChannelTitle = videoOwnerChannelTitle
        self.__videoOwnerChannelId = videoOwnerChannelId
        self.__video = None
        
    def get_video(self, youtube_client):
        if not self.__video:
            self.__video = FindVideo(self.__videoId).find_video(youtube_client)
        return self.__video

# %%
class PlayList:
    def __init__(self, id, channelId, title, description, thumbnails, channelTitle, 
                itemCount, player):
        self.__id = id
        self.__channelId = channelId
        self.__title = title
        self.__description = description
        self.__thumbnails = thumbnails
        self.__channelTitle = channelTitle
        self.__itemCount = itemCount
        self.__player = player
        self.__playlist_items = []
        self.__videos = []
        
    def get_playlist_items(self, youtube_client):
        if not self.__playlist_items:
            basic_info_params = self.__generate_basic_info_params()
            search_request = youtube_client.playlistItems().list(
                **basic_info_params
            )
            search_response = search_request.execute()
            parsed_response = self.__parse_playlist_items(search_response)
            self.__playlist_items = [PlaylistItem(**item) for item in parsed_response]
        return self.__playlist_items
    
    def get_videos(self, youtube_client):
        if not self.__videos:
            play_list_items = self.get_playlist_items(youtube_client)
            for playlist_item in play_list_items:
                self.__videos.append(playlist_item.get_video(youtube_client))
        return self.__videos
    
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            part='id,snippet,contentDetails',
            playlistId=self.__id
        ) 
        return basic_info_params
    
    def __parse_playlist_items(self, search_response):
        playlist_items = []
        items = search_response['items']
        for item in items:
            playlist_item = dict()
            playlist_item['id'] = item['id']
            playlist_item['publishedAt'] = item['snippet']['publishedAt']
            playlist_item['channelId'] = item['snippet']['channelId']
            playlist_item['title'] = item['snippet']['title']
            playlist_item['description'] = item['snippet']['description']
            playlist_item['thumbnails'] = item['snippet']['thumbnails']
            playlist_item['channelTitle'] = item['snippet']['channelTitle']
            playlist_item['position'] = item['snippet']['position']
            playlist_item['videoId'] = item['snippet']['resourceId']['videoId']
            playlist_item['videoOwnerChannelTitle'] = item['snippet']['videoOwnerChannelTitle']
            playlist_item['videoOwnerChannelId'] = item['snippet']['videoOwnerChannelId']
            playlist_items.append(playlist_item)
        return playlist_items
    
    def get_playlist_thumbnail(self):
        return self.__thumbnails['standard']['url']
    
    def get_playlist_title(self):
        return self.__title
    
    def get_playlist_channel_title(self):
        pass

# %%
class FindPlaylist:
    def __init__(self, playlist_id: str):
        """Find the video with the given id."""
        self.__playlist_id = playlist_id
        
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            id=self.__playlist_id,
            part='id,snippet,contentDetails,player',
        ) 
        return basic_info_params
    
    def find_playlist(self, youtube_client):
        """Find the video."""
        basic_info_params = self.__generate_basic_info_params()
        search_request = youtube_client.playlists().list(
                **basic_info_params
            )
        search_response = search_request.execute()
        parsed_response = self.__parse_playlist(search_response)
        youtube_playlist = PlayList(**parsed_response)
        return youtube_playlist
    
    def __parse_playlist(self, search_response):
        playlist_details = dict()
        items = search_response['items'][0]
        playlist_details['id'] = items['id']
        playlist_details['channelId'] = items['snippet']['channelId']
        playlist_details['title'] = items['snippet']['title']
        playlist_details['description'] = items['snippet']['description']
        playlist_details['thumbnails'] = items['snippet']['thumbnails']
        playlist_details['channelTitle'] = items['snippet']['channelTitle']
        playlist_details['itemCount'] = items['contentDetails']['itemCount']
        playlist_details['player'] = items['player']['embedHtml']
        return playlist_details

# %%
class PlaylistSearch(YouTubeSearch):
    __MAX_RESULTS = 10
    __REGION_CODE = 'US'
    
    def __init__(self, query_string: str):
        self.__type = YouTubeSearchType.PLAYLIST
        self.__query = YouTubeSearchQuery(query_string)
        
    def __get_query(self):
        return self.__query.query_string
        
    def basic_info(self):
        basic_info_params = self.__generate_basic_info_params()
        return basic_info_params
    
    def advanced_info(self):
        pass
    
    def all_info(self):
        pass
    
    def __generate_basic_info_params(self):
        basic_info_params = dict(
            part='id',
            type=self.__type,
            q=self.__get_query(),
            maxResults=self.__MAX_RESULTS,
        ) 
        return basic_info_params
    
    def search_playlist(self, youtube_client, search_type='basic'):
        search_response = None
        if search_type == 'basic':
            basic_info_params = self.__generate_basic_info_params()
            search_request = youtube_client.search().list(
                **basic_info_params
            )
            search_response = search_request.execute()
            playlist_ids = self.__parse_playlists(search_response)
            play_lists = [FindPlaylist(playlist_id).find_playlist(youtube_client)
                         for playlist_id in playlist_ids]
        return play_lists
    
    def __parse_playlists(self, search_response):
        playlists_ids = []
        items = search_response['items']
        for item in items:
            playlists_ids.append(item['id']['playlistId'])
        return playlists_ids

# %%
class YouTubeChannel:
    def __init__(self, id, title, description, customUrl, publishedAt, thumbnails, statistics):
        self.__id = id
        self.__title = title
        self.__description = description
        self.__customUrl = customUrl
        self.__publishedAt = publishedAt
        self.__thumbnails = thumbnails
        self.__statistics = statistics
        
    def get_channel_id(self):
        return self.__id
    
    def get_channel_title(self):
        return self.__title
        
    def get_channel_thumbnail(self):
        thumbnail = ''
        if self.__thumbnails:
            if self.__thumbnails.get('default'):
                thumbnail = self.__thumbnails.get('default').get('url')
            elif self.__thumbnails.get('medium'):
                thumbnail = self.__thumbnails.get('medium').get('url')
            elif self.__thumbnails.get('high'):
                thumbnail = self.__thumbnails.get('high').get('url')
            elif self.__thumbnails.get('standard'):
                thumbnail = self.__thumbnails.get('standard').get('url')
            elif self.__thumbnails.get('maxres'):
                thumbnail = self.__thumbnails.get('maxres').get('url')
        return thumbnail
    
    def __repr__(self) -> str:
        return f"YouTubeChannel(id={self.get_channel_id()}, channel_title={self.get_channel_title()})"

# %%
class FindChannel:       
    def __init__(self, youtube_client):
        self.__youtube_client = youtube_client
        
    def __generate_basic_info_params(self, channel_id):
        basic_info_params = dict(
            id=channel_id,
            part='id,snippet,contentDetails,contentOwnerDetails,statistics,topicDetails',
        ) 
        return basic_info_params
    
    def find_channel_by_name(self):
        pass
    
    def find_channel_by_id(self, channel_id):
        """Find the video."""
        basic_info_params = self.__generate_basic_info_params(channel_id)
        search_request = self.__youtube_client.channels().list(
                **basic_info_params
            )
        search_response = search_request.execute()
        parsed_response = self.__parse_channel(search_response)
        youtube_channel = YouTubeChannel(**parsed_response)
        return youtube_channel
    
    def __parse_channel(self, search_response):
        channel_details = {}
        items = search_response['items'][0]
        channel_details['id'] = items['id']
        channel_details['title'] = items['snippet']['title']
        channel_details['description'] = items['snippet']['description']
        channel_details['customUrl'] = items['snippet']['customUrl']
        channel_details['publishedAt'] = items['snippet']['publishedAt']
        channel_details['thumbnails'] = items['snippet']['thumbnails']
        channel_details['statistics'] = dict()
        channel_details['statistics']['viewCount'] = items['statistics']['viewCount']
        channel_details['statistics']['subscriberCount'] = items['statistics']['subscriberCount']
        channel_details['statistics']['videoCount'] = items['statistics']['videoCount']
        return channel_details

# %%
# class YouTube:
#     def __init__(self):
#         self.__youtube_api_auth = YouTubeAPIAuth()
#         self.__youtube_client = None
#         self.__video_categories = []
        
#     def get_credentials_path(self):
#         return self.__youtube_api_auth.get_credentials_path()
        
#     def authenticate_from_client_secrets_file(self, client_secrets_file: str, 
#                 credentials_path: str = ''):
#         self.__youtube_client = self.__youtube_api_auth.authenticate_from_client_secrets_file(client_secrets_file, credentials_path)
#         return self.__youtube_client
    
#     def authenticate_from_credentials(self, credentials_path: str):
#         self.__youtube_client = self.__youtube_api_auth.authenticate_from_credentials(credentials_path)
#         return self.__youtube_client
    
#     def generate_credentials(self, client_secrets_file: str, credentials_path: str = ''):
#         self.__youtube_api_auth.generate_credentials(client_secrets_file, credentials_path)
        
#     def get_youtube(self):
#         return self.__youtube_client
    
#     def search_videos(self, query_string: str) -> list[str]:
#         try:
#             videos = VideoSearch().search_video(query_string, self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return videos
    
#     def find_related_videos(self, youtube_video):
#         related_videos = VideoSearch().search_related_videos(youtube_video, self.__youtube_client)
#         return related_videos
    
#     def find_most_popular_videos_by_region(self, region_code):
#         try:
#             most_popular_videos_by_region = VideoSearch().search_most_popular_videos_by_region(
#                 region_code, self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return most_popular_videos_by_region
    
#     def search_playlists(self, query_string: str) -> list[str]:
#         try:
#             playlists = PlaylistSearch(query_string).search_playlist(self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return playlists
    
#     def search_channels(self, query_string: str) -> list[str]:
#         try:
#             channels = ChannelSearch(query_string).search_channels(self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return channels
    
#     def get_video_categories(self):
#         if not self.__video_categories:
#             try:
#                 self.__video_categories = SearchYouTubeVideoCategories(self.__youtube_client).get_youtube_video_categories()
#             except HttpError as e:
#                 raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return self.__video_categories
    
#     def find_most_popular_videos_by_category(self, category_id):
#         try:
#             most_popular_videos_by_category = VideoSearch().search_most_popular_videos_by_category(
#                 category_id, self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return most_popular_videos_by_category
    
#     def find_video_by_url(self, video_url: str):
#         """Get a specific video given the video url."""
#         video_id = self.__get_video_id(video_url)
#         return self.find_video_by_id(video_id)
        
#     def find_video_by_id(self, video_id: str):
#         """Find a video by id."""
#         try:
#             youtube_video = FindVideo(video_id).find_video(self.__youtube_client)
#         except HttpError as e:
#             raise QuotasExceededException('You have exceeded your daily quota limit.')
#         return youtube_video
    
#     @staticmethod
#     def __get_video_id(video_url: str) -> str:
#         """Get vdeo ID from video url"""
#         if not video_url:
#             raise ValueError('The video_ur has to be provided.')
#         if not isinstance(video_url, str):
#             raise TypeError('Te video_url has to be a string.')
#         if '=' not in video_url:
#             url_format = 'https://www.youtube.com/watch?v=Dqdu-FsBk0s'
#             raise ValueError(f'The video_url should be of the format "{url_format}"')
#         video_url = video_url.split('=')[1]
#         return video_url

# %%
class YouTube:
    MAX_RESULTS = 20
    REGION_CODE = 'us'
    
    def __init__(self):
        self.__youtube_api_auth = YouTubeAPIAuth()
        self.__youtube_client = None
        self.__video_categories = []
        
    def get_credentials_path(self):
        return self.__youtube_api_auth.get_credentials_path()
        
    def authenticate_from_client_secrets_file(self, client_secrets_file: str, 
                credentials_path: str = ''):
        self.__youtube_client = self.__youtube_api_auth.authenticate_from_client_secrets_file(client_secrets_file, credentials_path)
        return self.__youtube_client
    
    def authenticate_from_credentials(self, credentials_path: str):
        self.__youtube_client = self.__youtube_api_auth.authenticate_from_credentials(credentials_path)
        return self.__youtube_client
    
    def generate_credentials(self, client_secrets_file: str, credentials_path: str = ''):
        self.__youtube_api_auth.generate_credentials(client_secrets_file, credentials_path)
        
    def get_youtube(self):
        return self.__youtube_client
    
    def get_video_categories(self):
        if not self.__video_categories:
            self.__video_categories = SearchYouTubeVideoCategories(self.__youtube_client).get_youtube_video_categories()
        return self.__video_categories
    
    def search_videos(self, query_string: str) -> list[str]:
        self.__video_search = VideoSearch(self.__youtube_client)
        self.__previous_page_token, self.__next_page_token, videos = self.__video_search.search_videos(query_string)
        return videos
    
    def get_video_collections(self):
        return self.__video_search.get_videos()
    
    def find_related_videos(self, youtube_video):
        video_search = VideoSearch(self.__youtube_client)
        previous_page_token, next_page_token, related_videos = video_search.search_related_videos(youtube_video)
        return related_videos
    
    def find_most_popular_videos_by_region(self, region_code):
        most_popular_videos_by_region = VideoSearch().search_most_popular_videos_by_region(
            region_code, self.__youtube_client)
        return most_popular_videos_by_region
    
    def find_most_popular_videos_by_category(self, category_id):
        most_popular_videos_by_category = VideoSearch().search_most_popular_videos_by_category(
            category_id, self.__youtube_client)
        return most_popular_videos_by_category
    
    def find_video_by_url(self, video_url: str):
        """Get a specific video given the video url."""
        video_id = self.__get_video_id(video_url)
        return self.find_video_by_id(video_id)
        
    def find_video_by_id(self, video_id: str):
        """Find a video by id."""
        youtube_video = FindVideo(self.__youtube_client).find_video(video_id)
        return youtube_video
    
    @staticmethod
    def __get_video_id(video_url: str) -> str:
        """Get vdeo ID from video url"""
        if not video_url:
            raise ValueError('The video_ur has to be provided.')
        if not isinstance(video_url, str):
            raise TypeError('Te video_url has to be a string.')
        if '=' not in video_url:
            url_format = 'https://www.youtube.com/watch?v=Dqdu-FsBk0s'
            raise ValueError('Te video_url should be of the format "{url_format}"')
        video_url = video_url.split('=')[1]
        return video_url

# %%
youtube = YouTube()
client_secrets_file = '/home/lyle/Downloads/python_learning_site.json'
youtube_client = youtube.authenticate_from_client_secrets_file(client_secrets_file)

# %%
videos = youtube.search_videos('intermediate python programming')

# %%
videos
# Out:
# [YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={}),
#  YouTubeVideo(video_details={})]

# %%
videos[0].to_dict()
# Out:
# {'video_id': 'HGOBQPFzWKo',
#  'video_title': 'Intermediate Python Programming Course',
#  'video_description': 'Take your Python skills to the next level with this intermediate Python course. First, you will get a review of basic concepts such as lists, strings, and dictionaries, but with an emphasis on some lesser known capabilities. Then, you will learn more advanced topics such as threading, multiprocessing, context managers, generators, and more.\n\n💻 Code: https://github.com/python-engineer/python-engineer-notebooks/tree/master/advanced-python\n\n🎥 Course from Patrick Loeber. Check out his channel: https://www.youtube.com/channel/UCbXgNpp0jedKWcQiULLbDTA\n\n🔗 Written Tutorials from Patrick: https://www.python-engineer.com/courses/advancedpython/\n\n⭐️ Course Contents ⭐️\n⌨️ (0:00:00) Intro\n⌨️ (0:00:56) Lists\n⌨️ (0:16:30) Tuples\n⌨️ (0:29:49) Dictionaries\n⌨️ (0:42:40) Sets\n⌨️ (0:58:44) Strings\n⌨️ (1:22:50) Collections\n⌨️ (1:36:43) Itertools\n⌨️ (1:51:50) Lambda Functions\n⌨️ (2:04:03) Exceptions and Errors\n⌨️ (2:20:10) Logging\n⌨️ (2:42:20) JSON\n⌨️ (2:59:42) Random Numbers\n⌨️ (3:14:23) Decorators\n⌨️ (3:35:32) Generators\n⌨️ (3:53:29) Threading vs Multiprocessing\n⌨️ (4:07:59) Multithreading\n⌨️ (4:31:05) Multiprocessing\n⌨️ (4:53:26) Function Arguments\n⌨️ (5:17:28) The Asterisk (*) Operator\n⌨️ (5:30:19) Shallow vs Deep Copying\n⌨️ (5:40:07) Context Managers\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news',
#  'video_thumbnail': 'https://i.ytimg.com/vi/HGOBQPFzWKo/default.jpg',
#  'video_tags': ['python course',
#   'python tutorial',
#   'python',
#   'intermediate python',
#   'python nprogramming'],
#  'channel_id': 'UC8butISFwT-Wl7EV0hUK0BQ',
#  'channel_title': 'freeCodeCamp.org',
#  'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXPR4dSz0wwP-elkeiWUMnfZlCtNZP8Rd-tmFOZYg=s88-c-k-c0x00ffffff-no-rj'}

# %%
search = VideoSearch(youtube_client)
related_videos = search.search_related_videos(videos[0])

# %%
related_videos
# Out:
# ('',
#  'CAoQAA',
#  [YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={})])

# %%
related_videos = youtube.find_related_videos(videos[0])

# %%
related_videos
# Out:
# ('',
#  'CAoQAA',
#  [YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={}),
#   YouTubeVideo(video_details={})])

# %%
youtube.find_video_by_id(videos[0].get_video_id())
# Out:
# YouTubeVideo(video_details={})

# %%
videos[0].get_video_id()
# Out:
# 'HGOBQPFzWKo'

# %%
videos[0].to_dict()
# Out:
# {'video_id': 'HGOBQPFzWKo',
#  'video_title': 'Intermediate Python Programming Course',
#  'video_description': 'Take your Python skills to the next level with this intermediate Python course. First, you will get a review of basic concepts such as lists, strings, and dictionaries, but with an emphasis on some lesser known capabilities. Then, you will learn more advanced topics such as threading, multiprocessing, context managers, generators, and more.\n\n💻 Code: https://github.com/python-engineer/python-engineer-notebooks/tree/master/advanced-python\n\n🎥 Course from Patrick Loeber. Check out his channel: https://www.youtube.com/channel/UCbXgNpp0jedKWcQiULLbDTA\n\n🔗 Written Tutorials from Patrick: https://www.python-engineer.com/courses/advancedpython/\n\n⭐️ Course Contents ⭐️\n⌨️ (0:00:00) Intro\n⌨️ (0:00:56) Lists\n⌨️ (0:16:30) Tuples\n⌨️ (0:29:49) Dictionaries\n⌨️ (0:42:40) Sets\n⌨️ (0:58:44) Strings\n⌨️ (1:22:50) Collections\n⌨️ (1:36:43) Itertools\n⌨️ (1:51:50) Lambda Functions\n⌨️ (2:04:03) Exceptions and Errors\n⌨️ (2:20:10) Logging\n⌨️ (2:42:20) JSON\n⌨️ (2:59:42) Random Numbers\n⌨️ (3:14:23) Decorators\n⌨️ (3:35:32) Generators\n⌨️ (3:53:29) Threading vs Multiprocessing\n⌨️ (4:07:59) Multithreading\n⌨️ (4:31:05) Multiprocessing\n⌨️ (4:53:26) Function Arguments\n⌨️ (5:17:28) The Asterisk (*) Operator\n⌨️ (5:30:19) Shallow vs Deep Copying\n⌨️ (5:40:07) Context Managers\n\n--\n\nLearn to code for free and get a developer job: https://www.freecodecamp.org\n\nRead hundreds of articles on programming: https://freecodecamp.org/news',
#  'video_thumbnail': 'https://i.ytimg.com/vi/HGOBQPFzWKo/default.jpg',
#  'video_tags': ['python course',
#   'python tutorial',
#   'python',
#   'intermediate python',
#   'python nprogramming'],
#  'channel_id': 'UC8butISFwT-Wl7EV0hUK0BQ',
#  'channel_title': 'freeCodeCamp.org',
#  'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXPR4dSz0wwP-elkeiWUMnfZlCtNZP8Rd-tmFOZYg=s88-c-k-c0x00ffffff-no-rj'}

# %%
videos[0].get_video_comments()
# Out:
# [YouTubeComment(id='UgxhsgT0TB1L46coSCl4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgzWip4i-I18FHGnrF14AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgzlYA9XcmFy3H4zvC14AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgwfYg96MRWRasIgZ994AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgzitDv1zd0IQ99hV2F4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='Ugx8BIsFuOhfPCazerh4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgzHNSC1BbAZxp-repR4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgwMoSVbkHwom2S6g2R4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgzJtNQPGQMbjAvINUB4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgxbxWOQHIOCFM8Jfdh4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgysxYgdbXafHo_bEIZ4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgyWyMuOxqXZT7r-7XZ4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgwiHBWh-qgVpkdtZpF4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='Ugzn-1KZaMYT8QXINLx4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgwXsz_VM7ev0IJFE1R4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=2),
#  YouTubeComment(id='Ugw6dB0tvkJEJEKxWlp4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=1),
#  YouTubeComment(id='UgzVaAEx3qiLE-6GlYB4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='UgxLr8TB40xjTxGXOzt4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='Ugy30Qz3z2CyOC5tJ_B4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0),
#  YouTubeComment(id='Ugw-5bWhQenYYRRLA9N4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0)]

# %%
comments = videos[0].get_video_comments()

# %%
comments[0]
# Out:
# YouTubeComment(id='UgxhsgT0TB1L46coSCl4AaABAg', videoId='HGOBQPFzWKo',         totalReplyCount=0)

# %%
comments[0].get_comment()
# Out:
# {'id': 'UgxhsgT0TB1L46coSCl4AaABAg',
#  'videoId': 'HGOBQPFzWKo',
#  'totalReplyCount': 0,
#  'textDisplay': 'Does this course cover all the basics of python for beginners',
#  'authorDisplayName': 'Bright Gideon',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUBcnV-vueWK8-nAb3zYjUO2c8InZqui4_rbVI5Wg74eW6gAog0vlYRmGltHR2q=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelId': 'UCblhWhFuUQ7S11XHhKpzzMg',
#  'likeCount': 0,
#  'publishedAt': '2023-03-29T11:16:23Z',
#  'updatedAt': '2023-03-29T11:16:23Z'}

# %%
comments = [comment.get_comment() for comment in videos[0].get_video_comments()]
comments
# Out:
# [{'id': 'UgxhsgT0TB1L46coSCl4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Does this course cover all the basics of python for beginners',
#   'authorDisplayName': 'Bright Gideon',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUBcnV-vueWK8-nAb3zYjUO2c8InZqui4_rbVI5Wg74eW6gAog0vlYRmGltHR2q=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCblhWhFuUQ7S11XHhKpzzMg',
#   'likeCount': 0,
#   'publishedAt': '2023-03-29T11:16:23Z',
#   'updatedAt': '2023-03-29T11:16:23Z'},
#  {'id': 'UgzWip4i-I18FHGnrF14AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Lists ✓<br>Tuples ✓<br>Dictionary ×<br>Sets ×',
#   'authorDisplayName': 'Castro',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXV5DpixDFefvsGv5M5LVwYACab6MmOy0nY8OV1Ng=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCCEidLinyfexs-UyNiCNiew',
#   'likeCount': 0,
#   'publishedAt': '2023-03-29T10:17:29Z',
#   'updatedAt': '2023-03-30T21:49:18Z'},
#  {'id': 'UgzlYA9XcmFy3H4zvC14AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=31m38s">31:38</a> (≖ ͜ʖ≖)',
#   'authorDisplayName': 'Breeze',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJW8JzG9D9b7DZSXgSqD5iN_FQvnXykKQkZUYiBz4w=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCC0dzpKZvo2Zzj_qAeIbdNQ',
#   'likeCount': 0,
#   'publishedAt': '2023-03-28T18:28:01Z',
#   'updatedAt': '2023-03-28T18:28:01Z'},
#  {'id': 'UgwfYg96MRWRasIgZ994AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Why intermediate course goes through things like ”list can have duplicate items”.. 😮\u200d💨',
#   'authorDisplayName': 'JvB',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXrvJy4EHxd7NfIBsXqZ6n8Q-rP3Rqsrs4S4Q=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCUc4wFfdyucOpDdFFSX8-rg',
#   'likeCount': 0,
#   'publishedAt': '2023-03-22T14:43:58Z',
#   'updatedAt': '2023-03-22T14:43:58Z'},
#  {'id': 'UgzitDv1zd0IQ99hV2F4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'How do you print the output of python in vscode?',
#   'authorDisplayName': 'Tiago Salema',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/5H5rvykGYh6_eXoFl3Wji_GZROevzTLdgpGOXXMNSp3UtbJ0PduS8UwiaP0fYzEYQW-AIHhR=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC-mQmMQe0u_n4B6CtLA7qOg',
#   'likeCount': 0,
#   'publishedAt': '2023-03-12T23:12:57Z',
#   'updatedAt': '2023-03-12T23:12:57Z'},
#  {'id': 'Ugx8BIsFuOhfPCazerh4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Hello I got this error ModuleNotFoundError: No module named &#39;intertools&#39;. I installed python 3.11 and it should have come with the package. I can&#39;t seem to find any solution online. Does anyone know why? Much appreciated.',
#   'authorDisplayName': 'Mitchell Tsui',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWE2kBBz2S2IhrcfAMgYm6SHFetZWr_FADc9rP3kw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC5Nu1B4AgAV6UHwkYg8FxJg',
#   'likeCount': 0,
#   'publishedAt': '2023-03-11T13:58:58Z',
#   'updatedAt': '2023-03-11T13:58:58Z'},
#  {'id': 'UgzHNSC1BbAZxp-repR4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Thank you sir',
#   'authorDisplayName': 'WNF Draco',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/Vu2Cj--VV4bZ2BV_WezyVdaA2rMidvMp8EBMdPNhf8V8azEsfFdOJsWheh90PmSafnAeS8DD=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCbCjqeGXMQXecfe-jlVWJjQ',
#   'likeCount': 1,
#   'publishedAt': '2023-03-10T09:10:54Z',
#   'updatedAt': '2023-03-10T09:10:54Z'},
#  {'id': 'UgwMoSVbkHwom2S6g2R4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'The switching of Max&#39;s age between 28 and 27 is really bothering me 😂 great tutorial btw',
#   'authorDisplayName': 'mattman',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/7aYnvSkPv0uYxtld-lsU2JcQ2c44hnzEYvI7r0rJh3Dz3gVcYdkAWO5FsiIBt0v2v6OZppla=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCDcIXmFNkHC9WlQt7ADQNaQ',
#   'likeCount': 0,
#   'publishedAt': '2023-03-10T04:06:08Z',
#   'updatedAt': '2023-03-10T04:06:08Z'},
#  {'id': 'UgzJtNQPGQMbjAvINUB4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Is there an expert level tutorial series?',
#   'authorDisplayName': 'Sheiphan Joseph',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWBwxugNqRZoUeSBS1FC5YfcQwsX7gJomv2v-mSJaOY_m8xiMndF1hES1gJ1_Xm=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCGEb7l163jzFuGBYHs26tXQ',
#   'likeCount': 1,
#   'publishedAt': '2023-03-01T02:06:44Z',
#   'updatedAt': '2023-03-01T02:06:44Z'},
#  {'id': 'UgxbxWOQHIOCFM8Jfdh4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'A lot of people question what should i do after this <a href="http://course.exercise.you/">course.Exercise.You</a> can search for exercises for all this subject on internet or go for udemy where you find all the exercises encapsulated for the price of a night out, for example this : Master Python With Challenges from Beginner to Advanced.',
#   'authorDisplayName': 'Gabi Gherman',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJWF47nYzahakRwgptT77EylXDpLh2KnENNxZr3OjQ=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCF39I5CB7lurGnteOVd3C0w',
#   'likeCount': 0,
#   'publishedAt': '2023-02-28T20:49:48Z',
#   'updatedAt': '2023-02-28T20:49:48Z'},
#  {'id': 'UgysxYgdbXafHo_bEIZ4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Great job thanks. Fav statement by far is mydict pop ^^',
#   'authorDisplayName': 'U. K.',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUxS6W1NdZcQuDBZUsrUEIY0tfuZIHWcDQYKdz-SA=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC2fZGxnJZMEk5DFYqWWJdxQ',
#   'likeCount': 0,
#   'publishedAt': '2023-02-26T10:57:44Z',
#   'updatedAt': '2023-02-26T11:01:41Z'},
#  {'id': 'UgyWyMuOxqXZT7r-7XZ4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'The first half has been super enlightening, but the second half seems over my head. Just made it to multithreading.',
#   'authorDisplayName': 'ParadymShift, Plant-BASED Ⓥegan Jedi',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC3cXCQGz-q738xSdAhdvuFw',
#   'likeCount': 1,
#   'publishedAt': '2023-02-24T02:57:57Z',
#   'updatedAt': '2023-02-24T02:57:57Z'},
#  {'id': 'UgwiHBWh-qgVpkdtZpF4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'I was doing great up until Exceptions and Errors. I understood some of that, but then when we got to Logging I was completely lost. Hopefully it gets better for me later on xD',
#   'authorDisplayName': 'ParadymShift, Plant-BASED Ⓥegan Jedi',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC3cXCQGz-q738xSdAhdvuFw',
#   'likeCount': 2,
#   'publishedAt': '2023-02-22T22:16:13Z',
#   'updatedAt': '2023-02-22T22:16:13Z'},
#  {'id': 'Ugzn-1KZaMYT8QXINLx4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=15m08s">15:08</a> List Comprehension<br><a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=42m43s">42:43</a> Set',
#   'authorDisplayName': 'Sakti Biswal',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJVi_razgIWCJ-fN7S-Igg5oHdPIArPai7DFrA=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC6Gnq2csRLQEa8ebcmtQXJA',
#   'likeCount': 0,
#   'publishedAt': '2023-02-19T20:20:46Z',
#   'updatedAt': '2023-02-19T20:44:09Z'},
#  {'id': 'UgwXsz_VM7ev0IJFE1R4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 2,
#   'textDisplay': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=33m40s">33:40</a>',
#   'authorDisplayName': 'Creepy Old Grandpa',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/80PpDmXNazBYx1kn_70obXsTEPhdRHQTwVTY8diTTmpCdJvgvl9Va1WKFVp7N3QDTmO9xWprPxs=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC-vSGzmPgZKxacikhL12dGQ',
#   'likeCount': 0,
#   'publishedAt': '2023-02-19T08:58:25Z',
#   'updatedAt': '2023-02-19T08:58:50Z'},
#  {'id': 'Ugw6dB0tvkJEJEKxWlp4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 1,
#   'textDisplay': 'so what are the fundamental differences between lists and tuples?',
#   'authorDisplayName': 'samiran Bhowmik',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJUou33PLa7a6GaCsOLAIRdJHMqQBVK-e2IQVvgDLA=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCjTgzfhtkozj71GsdjUbf9Q',
#   'likeCount': 0,
#   'publishedAt': '2023-02-19T03:49:26Z',
#   'updatedAt': '2023-02-19T03:49:26Z'},
#  {'id': 'UgzVaAEx3qiLE-6GlYB4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Very good! Clear explanations and straight to the point.',
#   'authorDisplayName': 'Mr. Freddie',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJXdttr2lqv-CTJcoDqjkCF2GzbQ72BgomUHah3Ckw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC1-4Fzdpj7U1n0-uleQ5NOQ',
#   'likeCount': 0,
#   'publishedAt': '2023-02-15T05:42:26Z',
#   'updatedAt': '2023-02-15T05:42:26Z'},
#  {'id': 'UgxLr8TB40xjTxGXOzt4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'This course is hella underrated. Deserves many more views!',
#   'authorDisplayName': 'ParadymShift, Plant-BASED Ⓥegan Jedi',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC3cXCQGz-q738xSdAhdvuFw',
#   'likeCount': 1,
#   'publishedAt': '2023-02-09T04:45:09Z',
#   'updatedAt': '2023-02-09T04:45:09Z'},
#  {'id': 'Ugy30Qz3z2CyOC5tJ_B4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': 'Wow, this feels like just what I needed and I only just begun. Thank you very much!',
#   'authorDisplayName': 'ParadymShift, Plant-BASED Ⓥegan Jedi',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UC3cXCQGz-q738xSdAhdvuFw',
#   'likeCount': 1,
#   'publishedAt': '2023-02-09T04:17:29Z',
#   'updatedAt': '2023-02-09T04:17:29Z'},
#  {'id': 'Ugw-5bWhQenYYRRLA9N4AaABAg',
#   'videoId': 'HGOBQPFzWKo',
#   'totalReplyCount': 0,
#   'textDisplay': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=2h44m00s">2:44:00</a>',
#   'authorDisplayName': 'The Filthy American',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AL5GRJU9h3l4RThH1rDCeqcVaRqzXkX-CJb7TY6KhntJ=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelId': 'UCZXFPHiNiVeDyZYuPPUqd1A',
#   'likeCount': 0,
#   'publishedAt': '2023-02-09T03:40:56Z',
#   'updatedAt': '2023-02-09T03:40:56Z'}]

# %%
from sqlalchemy_utils import database_exists
import os

# %%
def create_db_conn_string(POSTGRES_HOST, POSTGRES_PORT, POSTGRES_USER, 
                          POSTGRES_PASSWORD, POSTGRES_DB) -> str:
    """Create the database connection string.

    Creates the database connection string for a given flask environment.

    Returns
    -------
    db_connection_string: str
        The database connection string
    """
#     POSTGRES_HOST = os.environ["POSTGRES_HOST"]
#     POSTGRES_PORT = os.environ["POSTGRES_PORT"]
#     POSTGRES_USER = os.environ["POSTGRES_USER"]
#     POSTGRES_PASSWORD = os.environ["POSTGRES_PASSWORD"]
#     POSTGRES_DB = os.environ["POSTGRES_DB"]

    return f"postgresql://{POSTGRES_USER}:{POSTGRES_PASSWORD}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}"


def check_if_database_exists(db_connection_string: str) -> bool:
    """Check if database exists.

    Ensures that the database exists before starting the application.

    Attributes
    ----------
    db_connection: str
        The database URL

    Raises
    ------
    ValueError:
        If the db_connection_string is empty or is not a string.

    Returns
    -------
    db_exists: bool
        True if database exists or False if it does not
    """
    if not db_connection_string:
        raise ValueError("The db_connection_string cannot be a null value.")

    if not isinstance(db_connection_string, str):
        raise ValueError("The db_connection_string has to be string")

    db_exists = database_exists(db_connection_string)

    return db_exists

# %%
POSTGRES_HOST='localhost' 
POSTGRES_PORT=5432 
POSTGRES_USER='lyle' 
POSTGRES_PASSWORD='lyle'
POSTGRES_DB='python-learning-app'
check_if_database_exists(create_db_conn_string(POSTGRES_HOST, POSTGRES_PORT, 
                        POSTGRES_USER, POSTGRES_PASSWORD, POSTGRES_DB))
# Out:
# True

# %%
from typing import List
from typing import Optional
from sqlalchemy import ForeignKey
from sqlalchemy import String, Text
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship

# %%
class Base(DeclarativeBase):
    pass

# %%
from sqlalchemy import create_engine

db_conn = create_db_conn_string(POSTGRES_HOST, POSTGRES_PORT, 
                    POSTGRES_USER, POSTGRES_PASSWORD, POSTGRES_DB)
engine = create_engine(db_conn, echo=True)

# %%
class Channel(Base):
    __tablename__ = "youtube_channel"
    
    channel_id: Mapped[str] = mapped_column(primary_key=True)
    channel_name: Mapped[str] = mapped_column(String(250))
    channel_thumbnail: Mapped[str] = mapped_column(String(250))
        
    videos: Mapped[List["Video"]] = relationship(
         back_populates="channel", cascade="all, delete-orphan")
        
    def __repr__(self) -> str:
        return f"Channel(channel_id='{self.channel_id!r}', channel_name='{self.channel_name!r}')"
        

class Comment(Base):
    __tablename__ = "youtube_comment"
    
    comment_id: Mapped[str] = mapped_column(primary_key=True)
    comment_text: Mapped[str] = mapped_column(Text())
    comment_author_name: Mapped[str] = mapped_column(String(250))
    comment_author_thumbnail: Mapped[str] = mapped_column(String(250))
        
    video_id: Mapped[str] = mapped_column(ForeignKey("youtube_video.video_id"))
    video: Mapped["Video"] = relationship(back_populates="comments")
        
    def __repr__(self) -> str:
        return f"Comment(comment_id='{self.comment_id!r}', comment_text='{self.comment_text!r}')"
        
class Video(Base):
    __tablename__ = "youtube_video"
    
    video_id: Mapped[str] = mapped_column(primary_key=True)
    video_name: Mapped[str] = mapped_column(String(250))
    video_thumbnail: Mapped[str] = mapped_column(String(250))
        
    channel_id: Mapped[str] = mapped_column(ForeignKey("youtube_channel.channel_id"))
    channel: Mapped["Channel"] = relationship(back_populates="videos")
        
    comments: Mapped[List["Comment"]] = relationship(
         back_populates="video", cascade="all, delete-orphan")
        
    def __repr__(self) -> str:
        return f"Video(video_id='{self.video_id!r}', video_name='{self.video_name!r}')"

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-04-04 17:00:07,487 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-04-04 17:00:07,489 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-04-04 17:00:07,493 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-04-04 17:00:07,495 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-04-04 17:00:07,499 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-04-04 17:00:07,501 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-04-04 17:00:07,505 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:00:07,511 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-04-04 17:00:07,513 INFO sqlalchemy.engine.Engine [generated in 0.00233s] {'table_name': 'youtube_channel', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-04-04 17:00:07,521 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-04-04 17:00:07,522 INFO sqlalchemy.engine.Engine [cached since 0.01163s ago] {'table_name': 'youtube_comment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-04-04 17:00:07,527 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-04-04 17:00:07,530 INFO sqlalchemy.engine.Engine [cached since 0.01876s ago] {'table_name': 'youtube_video', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-04-04 17:00:07,534 INFO sqlalchemy.engine.Engine
# CREATE TABLE youtube_channel (
# 	channel_id VARCHAR NOT NULL,
# 	channel_name VARCHAR(250) NOT NULL,
# 	channel_thumbnail VARCHAR(250) NOT NULL,
# 	PRIMARY KEY (channel_id)
# )
#
#
# 2023-04-04 17:00:07,536 INFO sqlalchemy.engine.Engine [no key 0.00158s] {}
# 2023-04-04 17:00:07,551 INFO sqlalchemy.engine.Engine
# CREATE TABLE youtube_video (
# 	video_id VARCHAR NOT NULL,
# 	video_name VARCHAR(250) NOT NULL,
# 	video_thumbnail VARCHAR(250) NOT NULL,
# 	channel_id VARCHAR NOT NULL,
# 	PRIMARY KEY (video_id),
# 	FOREIGN KEY(channel_id) REFERENCES youtube_channel (channel_id)
# )
#
#
# 2023-04-04 17:00:07,552 INFO sqlalchemy.engine.Engine [no key 0.00183s] {}
# 2023-04-04 17:00:07,565 INFO sqlalchemy.engine.Engine
# CREATE TABLE youtube_comment (
# 	comment_id VARCHAR NOT NULL,
# 	comment_text TEXT NOT NULL,
# 	comment_author_name VARCHAR(250) NOT NULL,
# 	comment_author_thumbnail VARCHAR(250) NOT NULL,
# 	video_id VARCHAR NOT NULL,
# 	PRIMARY KEY (comment_id),
# 	FOREIGN KEY(video_id) REFERENCES youtube_video (video_id)
# )
#
#
# 2023-04-04 17:00:07,566 INFO sqlalchemy.engine.Engine [no key 0.00130s] {}
# 2023-04-04 17:00:07,577 INFO sqlalchemy.engine.Engine COMMIT

# %%
youtube = YouTube()
client_secrets_file = '/home/lyle/Downloads/python_learning_site.json'
youtube_client = youtube.authenticate_from_client_secrets_file(client_secrets_file)

# %%
videos = youtube.search_videos('intermediate python programming')

# %%
videos
# Out:
# [YouTubeVideo(id=HGOBQPFzWKo, video_title=Intermediate Python Programming Course),
#  YouTubeVideo(id=p15xzjzR9j0, video_title=Mastering Python - Everything You Need To Know To Become a Python Master),
#  YouTubeVideo(id=2S7Xxz9PhaU, video_title=Python Intermediate Tutorial #1 - Classes and Objects),
#  YouTubeVideo(id=qeOcZiSp3tE, video_title=Learn 8 Python Important Concepts Simplified [ Intermediate Python ]),
#  YouTubeVideo(id=txKBWtvV99Y, video_title=3 Mini Python Projects - For Intermediates),
#  YouTubeVideo(id=th4OBktqK1I, video_title=Learn Python With This ONE Project!),
#  YouTubeVideo(id=ePSQXjIMDho, video_title=Go from BEGINNER to INTERMEDIATE programmer with this 👩‍💻 #technology #programming #career),
#  YouTubeVideo(id=_uQrJ0TkZlc, video_title=Python Tutorial - Python Full Course for Beginners),
#  YouTubeVideo(id=XKHEtdqhLK8, video_title=Python Full Course for free 🐍),
#  YouTubeVideo(id=VchuKL44s6E, video_title=Python As Fast as Possible - Learn Python in ~75 Minutes)]

# %%
videos[0].get_video_channel()
# Out:
# YouTubeChannel(id=UC8butISFwT-Wl7EV0hUK0BQ, channel_title=freeCodeCamp.org)

# %%
freecodecamp = videos[0].get_video_channel()

# %%
related_videos = youtube.find_related_videos(videos[0])

# %%
related_videos
# Out:
# [YouTubeVideo(id=vEQ8CXFWLZU, video_title=3 PYTHON AUTOMATION PROJECTS FOR BEGINNERS),
#  YouTubeVideo(id=8mAITcNt710, video_title=Harvard CS50 – Full Computer Science University Course),
#  YouTubeVideo(id=7eh4d6sabA0, video_title=Python Machine Learning Tutorial (Data Science)),
#  YouTubeVideo(id=JeznW_7DlB0, video_title=Python Object Oriented Programming (OOP) - For Beginners),
#  YouTubeVideo(id=dam0GPOAvVI, video_title=Python Website Full Tutorial - Flask, Authentication, Databases & More),
#  YouTubeVideo(id=ZDa-Z5JzLYM, video_title=Python OOP Tutorial 1: Classes and Instances),
#  YouTubeVideo(id=p15xzjzR9j0, video_title=Mastering Python - Everything You Need To Know To Become a Python Master),
#  YouTubeVideo(id=th4OBktqK1I, video_title=Learn Python With This ONE Project!),
#  YouTubeVideo(id=qUeud6DvOWI, video_title=25 nooby Python habits you need to ditch)]

# %%
from sqlalchemy.orm import Session
from psycopg2.errors import UniqueViolation
from sqlalchemy import exc

# %%
with Session(engine) as session:
    for video in videos:
        video_channel = video.get_video_channel()
        channel = Channel(
            channel_id=video_channel.get_channel_id(),
            channel_name=video_channel.get_channel_title(),
            channel_thumbnail=video_channel.get_channel_thumbnail()
        )
        try:
            session.add(channel)
            session.commit()
        except exc.IntegrityError:
             session.rollback()
# Out:
# 2023-04-04 17:33:48,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,108 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,111 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'channel_id': 'UC8butISFwT-Wl7EV0hUK0BQ', 'channel_name': 'freeCodeCamp.org', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXPR4dSz0wwP-elkeiWUMnfZlCtNZP8Rd-tmFOZYg=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,122 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,131 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,134 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'channel_id': 'UC4JX40jDee_tINbkjycV4Sg', 'channel_name': 'Tech With Tim', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUwJSD45ADCwBAlVTlX4IYjb6FtlQKou8FAxcU_Sg=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,139 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,148 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,150 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC8wZnXYK_CGKlBcZp-GxYPA', 'channel_name': 'NeuralNine', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU0uaJzfr7RCNwmHII8LCJRydWXCxbSUZSSpqkvqQ=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,155 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,162 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,164 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC7EVSn5inapL20oPSwAwEUg', 'channel_name': 'Bek Brace', 'channel_thumbnail': 'https://yt3.ggpht.com/aH9VNPwHAPGWZjrH6KClDqxSjOLkf0stb-KW1lTAMebtt0c1oS_QrrDJ0mIQ8f9rLkUg8hH6Aw=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,169 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,175 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,177 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC4JX40jDee_tINbkjycV4Sg', 'channel_name': 'Tech With Tim', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUwJSD45ADCwBAlVTlX4IYjb6FtlQKou8FAxcU_Sg=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,181 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-04-04 17:33:48,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,188 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,190 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC4JX40jDee_tINbkjycV4Sg', 'channel_name': 'Tech With Tim', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUwJSD45ADCwBAlVTlX4IYjb6FtlQKou8FAxcU_Sg=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,193 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-04-04 17:33:48,199 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,202 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,203 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UCWI-ohtRu8eEeDj93hmUsUQ', 'channel_name': 'Coding with Lewis', 'channel_thumbnail': 'https://yt3.ggpht.com/XCrBBAMNF2JLmu2UIMGxDV6nzclwfcnOvsHfkit2mG2rbD07QlR4XClZg5RP2zoaovP4mKfMZA=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,207 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,213 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,215 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,218 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UCWv7vMbMWH4-V0ZXdmDpPBA', 'channel_name': 'Programming with Mosh', 'channel_thumbnail': 'https://yt3.ggpht.com/tBEPr-zTNXEeae7VZKSZYfiy6azzs9OHowq5ZvogJeHoVtKtEw2PXSwzMBKVR7W0MI7gyND8=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,223 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,230 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,233 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC4SVo0Ue36XCfOyb5Lh1viQ', 'channel_name': 'Bro Code', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXev2NIsDYSbxtF7rhC4IaUr8B6MiGw1B5plnmPug=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,237 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:48,243 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:48,244 INFO sqlalchemy.engine.Engine INSERT INTO youtube_channel (channel_id, channel_name, channel_thumbnail) VALUES (%(channel_id)s, %(channel_name)s, %(channel_thumbnail)s)
# 2023-04-04 17:33:48,246 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'channel_id': 'UC4JX40jDee_tINbkjycV4Sg', 'channel_name': 'Tech With Tim', 'channel_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUwJSD45ADCwBAlVTlX4IYjb6FtlQKou8FAxcU_Sg=s88-c-k-c0x00ffffff-no-rj'}
# 2023-04-04 17:33:48,252 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
with Session(engine) as session:
    for video in videos:
        video = Video(
            video_id=video.get_video_id(),
            video_name=video.get_video_title(),
            video_thumbnail=video.get_video_thumbnail(),
            channel_id=video.get_channel_id()
        )
        try:
            session.add(video)
            session.commit()
        except exc.IntegrityError:
             session.rollback()
# Out:
# 2023-04-04 17:33:53,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,176 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,179 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'HGOBQPFzWKo', 'video_name': 'Intermediate Python Programming Course', 'video_thumbnail': 'https://i.ytimg.com/vi/HGOBQPFzWKo/default.jpg', 'channel_id': 'UC8butISFwT-Wl7EV0hUK0BQ'}
# 2023-04-04 17:33:53,188 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,194 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,196 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,198 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'p15xzjzR9j0', 'video_name': 'Mastering Python - Everything You Need To Know To Become a Python Master', 'video_thumbnail': 'https://i.ytimg.com/vi/p15xzjzR9j0/default.jpg', 'channel_id': 'UC4JX40jDee_tINbkjycV4Sg'}
# 2023-04-04 17:33:53,204 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,208 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,211 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,212 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': '2S7Xxz9PhaU', 'video_name': 'Python Intermediate Tutorial #1 - Classes and Objects', 'video_thumbnail': 'https://i.ytimg.com/vi/2S7Xxz9PhaU/default.jpg', 'channel_id': 'UC8wZnXYK_CGKlBcZp-GxYPA'}
# 2023-04-04 17:33:53,217 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,222 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,223 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,225 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'qeOcZiSp3tE', 'video_name': 'Learn 8 Python Important Concepts Simplified [ Intermediate Python ]', 'video_thumbnail': 'https://i.ytimg.com/vi/qeOcZiSp3tE/default.jpg', 'channel_id': 'UC7EVSn5inapL20oPSwAwEUg'}
# 2023-04-04 17:33:53,229 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,235 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,236 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'txKBWtvV99Y', 'video_name': '3 Mini Python Projects - For Intermediates', 'video_thumbnail': 'https://i.ytimg.com/vi/txKBWtvV99Y/default.jpg', 'channel_id': 'UC4JX40jDee_tINbkjycV4Sg'}
# 2023-04-04 17:33:53,240 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,244 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,246 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,247 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'th4OBktqK1I', 'video_name': 'Learn Python With This ONE Project!', 'video_thumbnail': 'https://i.ytimg.com/vi/th4OBktqK1I/default.jpg', 'channel_id': 'UC4JX40jDee_tINbkjycV4Sg'}
# 2023-04-04 17:33:53,250 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,254 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,256 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,257 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'ePSQXjIMDho', 'video_name': 'Go from BEGINNER to INTERMEDIATE programmer with this 👩\u200d💻 #technology #programming #career', 'video_thumbnail': 'https://i.ytimg.com/vi/ePSQXjIMDho/default.jpg', 'channel_id': 'UCWI-ohtRu8eEeDj93hmUsUQ'}
# 2023-04-04 17:33:53,260 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,264 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,266 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': '_uQrJ0TkZlc', 'video_name': 'Python Tutorial - Python Full Course for Beginners', 'video_thumbnail': 'https://i.ytimg.com/vi/_uQrJ0TkZlc/default.jpg', 'channel_id': 'UCWv7vMbMWH4-V0ZXdmDpPBA'}
# 2023-04-04 17:33:53,269 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,272 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,274 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,275 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'XKHEtdqhLK8', 'video_name': 'Python Full Course for free 🐍', 'video_thumbnail': 'https://i.ytimg.com/vi/XKHEtdqhLK8/default.jpg', 'channel_id': 'UC4SVo0Ue36XCfOyb5Lh1viQ'}
# 2023-04-04 17:33:53,278 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:53,281 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:53,283 INFO sqlalchemy.engine.Engine INSERT INTO youtube_video (video_id, video_name, video_thumbnail, channel_id) VALUES (%(video_id)s, %(video_name)s, %(video_thumbnail)s, %(channel_id)s)
# 2023-04-04 17:33:53,284 INFO sqlalchemy.engine.Engine [cached since 2011s ago] {'video_id': 'VchuKL44s6E', 'video_name': 'Python As Fast as Possible - Learn Python in ~75 Minutes', 'video_thumbnail': 'https://i.ytimg.com/vi/VchuKL44s6E/default.jpg', 'channel_id': 'UC4JX40jDee_tINbkjycV4Sg'}
# 2023-04-04 17:33:53,288 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    for video in videos:
        for comment in video.get_video_comments():
            video_comment = comment.get_comment()
            cm = Comment(
                comment_id=video_comment['id'],
                comment_text=video_comment['textDisplay'],
                comment_author_name=video_comment['authorDisplayName'],
                comment_author_thumbnail=video_comment['authorProfileImageUrl'],
                video_id=video.get_video_id()
            )
            try:
                session.add(cm)
                session.commit()
            except exc.IntegrityError:
                 session.rollback()
# Out:
# 2023-04-04 17:33:58,118 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,120 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,126 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwGzOJgkxqw5brI4tR4AaABAg', 'comment_text': 'Comprehensive tutorial.  The only problem I see is the black background and the gray text makes it very difficult to follow along.  I do notice that most of the &quot;CODE&quot; presentation on YouTube use the same format &quot;Black Background and a non-emphasis on the text color.', 'comment_author_name': 'Max Tuck', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU4TsulCnNTSHPregX1eEXfhbquhOao03vBSQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,131 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,142 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,146 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwIjcwzCgWKl0Axp3l4AaABAg', 'comment_text': 'Love how this course gets straight to the point. Can&#39;t wait to finish it. Also, was mind blown that tuples are more efficient than lists. Never would have thought of that.', 'comment_author_name': 'GunHyun Jeong', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUVEfId6Fwm2AfKboCPKqUOdzjr-mJFX-A8afpT=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,150 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,156 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,158 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,160 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxhsgT0TB1L46coSCl4AaABAg', 'comment_text': 'Does this course cover all the basics of python for beginners', 'comment_author_name': 'Bright Gideon', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUBcnV-vueWK8-nAb3zYjUO2c8InZqui4_rbVI5Wg74eW6gAog0vlYRmGltHR2q=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,164 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,171 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,173 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzWip4i-I18FHGnrF14AaABAg', 'comment_text': 'Lists ✓<br>Tuples ✓<br>Dictionary ×<br>Sets ×', 'comment_author_name': 'Castro', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXV5DpixDFefvsGv5M5LVwYACab6MmOy0nY8OV1Ng=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,177 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,183 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,185 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,186 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzlYA9XcmFy3H4zvC14AaABAg', 'comment_text': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=31m38s">31:38</a> (≖ ͜ʖ≖)', 'comment_author_name': 'Breeze', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJW8JzG9D9b7DZSXgSqD5iN_FQvnXykKQkZUYiBz4w=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,191 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,196 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,198 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,200 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwfYg96MRWRasIgZ994AaABAg', 'comment_text': 'Why intermediate course goes through things like ”list can have duplicate items”.. 😮\u200d💨', 'comment_author_name': 'JvB', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXrvJy4EHxd7NfIBsXqZ6n8Q-rP3Rqsrs4S4Q=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,204 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,212 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,213 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,214 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzitDv1zd0IQ99hV2F4AaABAg', 'comment_text': 'How do you print the output of python in vscode?', 'comment_author_name': 'Tiago Salema', 'comment_author_thumbnail': 'https://yt3.ggpht.com/5H5rvykGYh6_eXoFl3Wji_GZROevzTLdgpGOXXMNSp3UtbJ0PduS8UwiaP0fYzEYQW-AIHhR=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,218 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,224 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,226 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,227 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugx8BIsFuOhfPCazerh4AaABAg', 'comment_text': 'Hello I got this error ModuleNotFoundError: No module named &#39;intertools&#39;. I installed python 3.11 and it should have come with the package. I can&#39;t seem to find any solution online. Does anyone know why? Much appreciated.', 'comment_author_name': 'Mitchell Tsui', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWE2kBBz2S2IhrcfAMgYm6SHFetZWr_FADc9rP3kw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,235 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,242 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,244 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,245 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzHNSC1BbAZxp-repR4AaABAg', 'comment_text': 'Thank you sir', 'comment_author_name': 'WNF Draco', 'comment_author_thumbnail': 'https://yt3.ggpht.com/Vu2Cj--VV4bZ2BV_WezyVdaA2rMidvMp8EBMdPNhf8V8azEsfFdOJsWheh90PmSafnAeS8DD=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,249 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,254 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,257 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,259 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwMoSVbkHwom2S6g2R4AaABAg', 'comment_text': 'The switching of Max&#39;s age between 28 and 27 is really bothering me 😂 great tutorial btw', 'comment_author_name': 'mattman', 'comment_author_thumbnail': 'https://yt3.ggpht.com/7aYnvSkPv0uYxtld-lsU2JcQ2c44hnzEYvI7r0rJh3Dz3gVcYdkAWO5FsiIBt0v2v6OZppla=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,262 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,268 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,270 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,272 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzJtNQPGQMbjAvINUB4AaABAg', 'comment_text': 'Is there an expert level tutorial series?', 'comment_author_name': 'Sheiphan Joseph', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWBwxugNqRZoUeSBS1FC5YfcQwsX7gJomv2v-mSJaOY_m8xiMndF1hES1gJ1_Xm=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,276 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,282 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,284 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,285 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxbxWOQHIOCFM8Jfdh4AaABAg', 'comment_text': 'A lot of people question what should i do after this <a href="http://course.exercise.you/">course.Exercise.You</a> can search for exercises for all t ... (42 characters truncated) ... ere you find all the exercises encapsulated for the price of a night out, for example this : Master Python With Challenges from Beginner to Advanced.', 'comment_author_name': 'Gabi Gherman', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWF47nYzahakRwgptT77EylXDpLh2KnENNxZr3OjQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,289 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,294 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,296 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,297 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgysxYgdbXafHo_bEIZ4AaABAg', 'comment_text': 'Great job thanks. Fav statement by far is mydict pop ^^', 'comment_author_name': 'U. K.', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUxS6W1NdZcQuDBZUsrUEIY0tfuZIHWcDQYKdz-SA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,300 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,305 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,307 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,308 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgyWyMuOxqXZT7r-7XZ4AaABAg', 'comment_text': 'The first half has been super enlightening, but the second half seems over my head. Just made it to multithreading.', 'comment_author_name': 'ParadymShift, Plant-BASED Ⓥegan Jedi', 'comment_author_thumbnail': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,312 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,316 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,318 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,319 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwiHBWh-qgVpkdtZpF4AaABAg', 'comment_text': 'I was doing great up until Exceptions and Errors. I understood some of that, but then when we got to Logging I was completely lost. Hopefully it gets better for me later on xD', 'comment_author_name': 'ParadymShift, Plant-BASED Ⓥegan Jedi', 'comment_author_thumbnail': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,343 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,351 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,353 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugzn-1KZaMYT8QXINLx4AaABAg', 'comment_text': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=15m08s">15:08</a> List Comprehension<br><a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=42m43s">42:43</a> Set', 'comment_author_name': 'Sakti Biswal', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVi_razgIWCJ-fN7S-Igg5oHdPIArPai7DFrA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,356 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,362 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,364 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,366 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwXsz_VM7ev0IJFE1R4AaABAg', 'comment_text': '<a href="https://www.youtube.com/watch?v=HGOBQPFzWKo&amp;t=33m40s">33:40</a>', 'comment_author_name': 'Creepy Old Grandpa', 'comment_author_thumbnail': 'https://yt3.ggpht.com/80PpDmXNazBYx1kn_70obXsTEPhdRHQTwVTY8diTTmpCdJvgvl9Va1WKFVp7N3QDTmO9xWprPxs=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,370 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,378 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,380 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugw6dB0tvkJEJEKxWlp4AaABAg', 'comment_text': 'so what are the fundamental differences between lists and tuples?', 'comment_author_name': 'samiran Bhowmik', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUou33PLa7a6GaCsOLAIRdJHMqQBVK-e2IQVvgDLA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,384 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,395 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,397 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,399 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzVaAEx3qiLE-6GlYB4AaABAg', 'comment_text': 'Very good! Clear explanations and straight to the point.', 'comment_author_name': 'Mr. Freddie', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXdttr2lqv-CTJcoDqjkCF2GzbQ72BgomUHah3Ckw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,403 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,410 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,411 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxLr8TB40xjTxGXOzt4AaABAg', 'comment_text': 'This course is hella underrated. Deserves many more views!', 'comment_author_name': 'ParadymShift, Plant-BASED Ⓥegan Jedi', 'comment_author_thumbnail': 'https://yt3.ggpht.com/iemT51hQ1TUzrfUhP3S0DDAadwwWTn3UebhZW7PPwXjJc16LcrfHE-c3e1VQS_yALd_ifpuJDw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'HGOBQPFzWKo'}
# 2023-04-04 17:33:58,415 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,422 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,425 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwYyqvGg_QZmItnDZJ4AaABAg', 'comment_text': 'Start mastering data structures and algorithms using AlgoExpert ;) Code: &quot;techwithtim&quot; for 10% off <a href="https://algoexpert.io/techwithtim">https://algoexpert.io/techwithtim</a>', 'comment_author_name': 'Tech With Tim', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUwJSD45ADCwBAlVTlX4IYjb6FtlQKou8FAxcU_Sg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,429 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,435 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,436 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,439 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzaaxdpZMT6IVW0qw14AaABAg', 'comment_text': 'Ok I&#39;m going to start with your beginner advice and see where we go from there! ^_^ thanks for making the video.', 'comment_author_name': 'skatebrothers06', 'comment_author_thumbnail': 'https://yt3.ggpht.com/QnJAH4wV3XoGnIaY7fU7pME3kK22FckhpbUn2kZObh_EK5Yv_NYhpT3hPDKDOInOB1jO2RmS=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,443 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,447 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,450 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,451 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxAFNESswws8cuEfDR4AaABAg', 'comment_text': 'As a Python enthusiast i couldn&#39;t pass the limit of basic skills because  i start and quit everytime but after watching this video i think i&#39; ... (176 characters truncated) ... ith python , i enjoy your videos everytime i watch they&#39;re always instructive and good to watch keep up the good work , greetings from Algeria 🇩🇿', 'comment_author_name': 'sami ramoul', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVLOo6PfluDsE0F2a0M8H4Mq6_HaUOlau3fbA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,455 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,461 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,463 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxSQpn9ow8OXVFUyJF4AaABAg', 'comment_text': 'Hi Tim thank you so much for sharing !', 'comment_author_name': 'Sarah B', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUMK196_ZnUfszUXFJQCddeiHAkFDGolZGTV4oz=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,469 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,475 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,477 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,479 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugz2jYFPZ1TQo65zqPh4AaABAg', 'comment_text': 'Thank you. Very helpfully :)', 'comment_author_name': 'Corey Hopkins', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ikhG1SvuKci6GZfXSpN_avE9TNFfCfQh8d11lITPCyuEp9L7rTr6BL2RBmZ1rHgtHSmpZf5k=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,484 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,491 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,492 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugx8l0nWyAtfywsQPW54AaABAg', 'comment_text': 'This basic af and i still don&#39;t get it.', 'comment_author_name': 'CoolGuy Nikolay42', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWVsEgCheS4V1kZG4yOeYUYVSNTP-CqYVJLU0PA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,497 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,501 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,504 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,509 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzHVngYS4BfxdSXKP54AaABAg', 'comment_text': 'Amazing, a clear path to Python mastery.<br>Thanks a lot, Tim!', 'comment_author_name': 'Islam H', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXPjUeHDawa3CIVfA9X9PaBWZVRdHLryYgrFI28=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,513 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,517 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,521 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,522 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxT5P6FGRnrJ0Xhc3F4AaABAg', 'comment_text': 'how long did it take for you to master python fully?', 'comment_author_name': 'rehevoli vras', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUya3VCo9BsYTEToPAf7xjdxAsuzXXCwQyBxe68Zv9WfeCeVw-vJzjKl_CV-AvB=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,527 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,540 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,542 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgyZZCchH0ZWxmS8u8F4AaABAg', 'comment_text': 'Excellent 🇮🇳', 'comment_author_name': 'Amit Pustake', 'comment_author_thumbnail': 'https://yt3.ggpht.com/FpEs-o7l3iQPXnSD6Xpk5qPYlnY6Z401AaEWzPAxCBer5LgnzeBvjdvwOEvIiIhL5W2QSXanb2U=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,549 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,554 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,557 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,558 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzqjdnlPp7tpwVUGXJ4AaABAg', 'comment_text': 'thank uuuuu!', 'comment_author_name': 'Nunuyeaa Sj', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWHbkzdW6su6TUy6h2o62C5kDjAnmmolCom82DuUg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,560 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,566 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,567 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwoSm3q3_d_wwWOfRR4AaABAg', 'comment_text': 'Hello Tim, are there any new features for python that came out in these 2 years of is this roadmap still the way to go?', 'comment_author_name': 'Kayd Zeal', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWi-05aSxvpfUQqIOjyWlUjC8p0Au9ef8xFuehexg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,570 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,573 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,575 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,576 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzMmSNAU6Atc1x0bNR4AaABAg', 'comment_text': 'Do you teach those things on your curso ? Is your curso just python ?', 'comment_author_name': 'Maycon NFT', 'comment_author_thumbnail': 'https://yt3.ggpht.com/9g8t2ikztc9fkNi-jz5gRGhT__KT1hxXnZiOYvl8WsQSF7JYgqoUpPNylzZ3nZyIcIWdqcKWgg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,579 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,583 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,585 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,586 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwWgugtjqn2VNc0NiV4AaABAg', 'comment_text': 'This is what I needed. Thank you very much!', 'comment_author_name': 'Dickson Wachai', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWs8X6FzL8Tlr-PJyjDyJYXaTdkEipRE9SljNA_Tg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,589 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,594 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,595 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugz3PC50CvweenJqJPx4AaABAg', 'comment_text': 'Thanks to this video, I have an action plan to improve my coding. I started coding in python but did&#39;nt know how or where to improve from. This gives a clear and concise idea of improvement', 'comment_author_name': 'Juniz 1982', 'comment_author_thumbnail': 'https://yt3.ggpht.com/cJoUg0aVjGCA1goJeSwLMo_pudmWhBfPna9616dWHXH2Ov3BTOPRcbRmCVFaLF8PAPzggiv6DGI=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,599 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,603 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,604 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,606 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxqfxEjM67mnG_Rgw54AaABAg', 'comment_text': 'This is amazing. evrything I need to know what kind of world I&#39;m stepping into', 'comment_author_name': 'Teddy Perera', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUTnig_PkZDlCJJXVcFCeBQPYp98tPjgNHYROer=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,609 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,612 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,614 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,615 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxcbFL76g-0cqPgBnx4AaABAg', 'comment_text': 'Good morning Tim , I would like to have a video on Introduction to VS Code . Please I will appreciate', 'comment_author_name': 'Enrique Adrian', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJW31eozdeqRtzzo4WIoylMZlYtuCNcEMw5gZA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,619 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,623 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,625 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugzf0jB0Rttp77gH3-R4AaABAg', 'comment_text': 'This is not a good video', 'comment_author_name': 'Maulik Goyal', 'comment_author_thumbnail': 'https://yt3.ggpht.com/_wyqojZ3UYAi51q9vpeIsLcVtdYwQ7i6qbt_hxlt3V3RcDCVnBUljYZHoagBwKm_nMlqnEl1MQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,628 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,631 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,633 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,634 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxApQaawac_gAmH9ex4AaABAg', 'comment_text': 'I will like to get a personal tutorial from Tech with Tim', 'comment_author_name': 'Chidiebere Ugwu', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJX4256bcNY59xbbSydbermj-oFiO1JZ2RKMlXo0ug=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,637 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,640 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,642 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,643 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgylKDm_0GTz0njRebB4AaABAg', 'comment_text': 'Thank you. This is the best explanation on the web!', 'comment_author_name': 'Victor Digital', 'comment_author_thumbnail': 'https://yt3.ggpht.com/W8o-6sYPQiqqWq6c7glh1YVvtuJH7xDeC8A36V77JjUU47flovlJeVsrgAoceKmckMAT3-ej9Hs=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,646 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,651 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,655 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,658 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugx5h4hjV6DPeGsBeE14AaABAg', 'comment_text': 'I used to read solo learn tutorial while travelling by train. My brain melted at generators of lambda functions. But it was fun :D', 'comment_author_name': 'Cookie Monster', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVk1bFfjBOXdvVeFD-HwOG97n_8RJnK3wiOdY7q=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'p15xzjzR9j0'}
# 2023-04-04 17:33:58,662 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,669 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,670 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzRtlrgxI5UjuBN0qZ4AaABAg', 'comment_text': 'Amazing. Thanks a lot!', 'comment_author_name': 'Eugen Malatov', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU9WACRk-BEppZpT4ps4Tgoaj44jiEPvMOP2Oky=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,674 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,682 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,684 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxqYnfSv5Do-_xusAB4AaABAg', 'comment_text': 'Camtasia has a feature to auto zoom on the window you are using. For users watching on mobile I suggest it so the text isn&#39;t tiny.', 'comment_author_name': 'CaspersCuts', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU64wywKonCj-ybo4zjvdkfKTZbsT__aKHx5Q=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,687 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,691 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,693 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,695 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzsJ7HfpqIf-sdn8Yp4AaABAg', 'comment_text': '<a href="http://www.youtube.com/results?search_query=%23problem">#problem</a><br>Sir please increase your font size because I can&#39;t watch the whole video in 480p or 720p with 1.5GB of data limit', 'comment_author_name': 'Piyush gupta', 'comment_author_thumbnail': 'https://yt3.ggpht.com/o-7IqLvJdE8DIrPqEAtQVxl84omsR3w0Qlls_jo77FqZSV64Dkaw_pM-iRc62cHM1SJwycRCmQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,704 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,709 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,712 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,714 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzacnZFsj0Jbvf1uoJ4AaABAg', 'comment_text': 'Screen is too small', 'comment_author_name': 'EDTN', 'comment_author_thumbnail': 'https://yt3.ggpht.com/YO48SIy2JfY4939JrVRpUHfe8PuXBvgUPL3H8XeUd9ZvJnWfhhTPy5n8NKolERbWqfFmCFuP=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,719 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,727 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,728 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzGsRiVRrm-Fl6gf254AaABAg', 'comment_text': 'Love these series. I&#39;m saving tons of time learning!. Thanks a lot!', 'comment_author_name': 'Juan Gomez', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU2HmP6RZoO3pSwjbe4-I7aDvHIrI4YnCz9AT-RZA=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,733 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,737 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,739 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,741 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzTJ-VJBOTmYuUyNC54AaABAg', 'comment_text': 'Great, watching this along with the others in the intermediate playlist, as a refresher and to learn multi-threading.<br><br>Great job :) compiling t ... (3 characters truncated) ... beginner, intermediate and advanced in a structured one after another sequence.<br><br>Gives it a very academical and methodical learning experience.', 'comment_author_name': 'Kira Shinigami', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXFAM762ib6m0ZXj1QybC55OtOOHDKKZx7GC8skvg=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,745 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,751 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,752 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxsCkxQ8UF2I4y4ZgJ4AaABAg', 'comment_text': 'Thank you. Hard to follow because the font is extremely small. Would be great if your future videos are zoomed out a bit.', 'comment_author_name': 'A Boima', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVoqy_0BERUFTN2ZCDkk7opeW7MRG_mhGQsOA=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,756 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,763 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,764 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgyfywHz3SM5VWmAU3J4AaABAg', 'comment_text': 'When you mention __init__() method you used the term &#39;constructor&#39; but I presume that this is not the same &quot;constructor&quot; as the ones we use in Java or other OO languages. Am I right?', 'comment_author_name': '도꼬마리', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJWUPJnvS7PKB4iFsyWb1kOiNtGO7_sY-2wqSw=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,768 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,772 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,774 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,777 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxxixsZZuvoFKKDxa14AaABAg', 'comment_text': 'I wish I could see what you were doing, but the text is way too small.<br><br>Hopefully, future videos in 2022/2023 will show a full screen IDE with larger font.', 'comment_author_name': 'Simon Williamson', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVsnBqECt8F-aNgtGSk46QzJaSvdudjj3ovBHuInxc=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,780 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,785 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,788 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,789 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgxjPKhtJD86KawDNwF4AaABAg', 'comment_text': 'I think we probably need to add &#39;self&#39; to get_older() function as well. I am not sure was getting error without it.', 'comment_author_name': 'Omkar Sinha', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUUoyeSSQ7T-8fmQemyp_rScx87vzv8SrkpEQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,793 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,798 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,800 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,802 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugycf3jDdjJRdJlybuh4AaABAg', 'comment_text': 'Very nice tutorial, thanks!', 'comment_author_name': 'Web64Dev', 'comment_author_thumbnail': 'https://yt3.ggpht.com/7IFVEqwjyRGcZDzoU5O6PJDSyexfr9azL7PrciBNnHzlGPhlypLJnteKD-nYnqCb7qV3RdVFSz0=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,806 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,812 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,815 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,818 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugxe7q0xz68vFtBmNwt4AaABAg', 'comment_text': 'Hey thanks for such a beautiful explanation but when I tried to create the class(same as you did, word by word) I got the error saying &quot;Person cannot take any argument&quot; what should I do?. I&#39;ve tried many things but it doesn&#39;t work', 'comment_author_name': 'Ronak Khurana', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXitEET3bTxSlVv-qoucvFwpcOccNdVxbJ3MbK61A=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,822 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,826 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,828 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,829 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'Ugww6fdmjcJT6XWCuzp4AaABAg', 'comment_text': 'UNDERRATED!!!!!!!!!!', 'comment_author_name': 'Hans Jürgens', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJX3NigyFMVoz8AyiWHQn8yr_94o4VRET9Cg3y4g=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,832 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,836 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,838 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,839 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgwqClzmcS1YXaFKcFV4AaABAg', 'comment_text': 'Thank you. Enjoying your tutorials', 'comment_author_name': 'Jane Papa', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUm-xta_ITGWoG5hdllSfwr3LwLVXNXX6uLlsQFvw=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,843 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,849 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,857 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:33:58,858 INFO sqlalchemy.engine.Engine [cached since 2010s ago] {'comment_id': 'UgzFwtco2tm9Rt1jQ8F4AaABAg', 'comment_text': 'Thanks for this comprehensive and useful content. It&#39;s really great. <br>Just a question, is it possible to start the series about functional programming in Python?', 'comment_author_name': 'Mehdi Mojaradi', 'comment_author_thumbnail': 'https://yt3.ggpht.com/HY90UdZ0b48QNl4_8zL99Boyl3gkVc-MZnhP60im2jKPeamNHn9zbLw_U4GG19XbHa6LQu6lJg=s48-c-k-c0x00ffffff-no-rj', 'video_id': '2S7Xxz9PhaU'}
# 2023-04-04 17:33:58,861 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:33:58,866 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:33:58,867 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# ...
# 2023-04-04 17:34:00,479 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgyULVtPvbn-jzblnKR4AaABAg', 'comment_text': 'author :  This videos in not for absolute beginners! so let`s starts with tutorial how to download this!', 'comment_author_name': 'Oriyon Muhabbatov', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXlRK4v8MGNdXkL_T4HolDrOxSBu40ZNh4lTnF7JQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,485 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,490 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,492 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,494 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgxmOHIHCOK9a_8q5m94AaABAg', 'comment_text': 'great video. thanks', 'comment_author_name': 'Jay Lee', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU0zLvWBHyELiYOZwIIxQRr11SdNbl7U-PuGhAP29E=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,497 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,501 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,504 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,506 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgwgRUzHyGEXAjoegrV4AaABAg', 'comment_text': 'AWESOME VIDEO! THANKS FOR THAT!<br><br>I&#39;m getting back to programming after a while and this was just PERFECT as a starting review.', 'comment_author_name': 'Palácio dos Cursos', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ZA3Q4nNHInKg-QjI328HGzPbWeBD0oGI-mJv35BODPikmj6aqVJ6mPqZFAjyGKj6YX1ZbBfu_A=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,510 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,514 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,518 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,521 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgzPPedB4YdNjkK21T54AaABAg', 'comment_text': 'this is awesome man. i program in a lot of languages and most cs videos put me to sleep while they spend 4 hrs explaining how to install it or what a for loop was. Ive put off learning ptthon for a decade. You made it less painful', 'comment_author_name': 'cdreid9999', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVDWuDeuiqtyTIIqrX1lHHjziM5PfcXBTOu3Q=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,525 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,532 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,534 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugzel6F0AavNB4SKuCZ4AaABAg', 'comment_text': 'Thanks Tim! Love your channel', 'comment_author_name': 'Ana Marcella Hauge', 'comment_author_thumbnail': 'https://yt3.ggpht.com/kOBJZyGEnpUel1wJt2Ht2PnOdi-5wltHKhrzJvlOHaH2sVCtEeAU-9LXisZcsUGa6b2H-EP3=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,538 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,545 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,546 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgwYutzCWqtGn4E-rH94AaABAg', 'comment_text': 'Helped me cram for a project! Thank you so much. Would recommend this video (don&#39;t recommend cramming;))', 'comment_author_name': 'BWG', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUW9AhGOveYsZCCawit_fzIbbRjGmwOoCEMI0T0aQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,549 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,554 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,555 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,557 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugz1v2dOtwg0VIfJUIR4AaABAg', 'comment_text': 'Wow. Is there more to know about Python ? Like an intermediate or advance level?', 'comment_author_name': 'Luis Murillo', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXf4f5-lxTbEGrjfJ8NVUywxIBsGK8hCaDpwi82xvuLUc5TOqVR1K-icM3bxwck=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,560 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,565 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,566 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,567 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugx6A83MfEhgldhkCS14AaABAg', 'comment_text': 'Oh man you are my hero. This is the best video for me to fast review Python. Thanks a lots!', 'comment_author_name': 'Ryo', 'comment_author_thumbnail': 'https://yt3.ggpht.com/X_5-IYfQm1sRYFCNWIy3CxmjY9EO1W-1n4cG0IX1UIhkwD5rPkD6y-u_PmlEWMtR5T6Jk4jorw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,571 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,576 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,577 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,578 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugyvgh9HZ8Yp4lwIDRl4AaABAg', 'comment_text': 'At <a href="https://www.youtube.com/watch?v=VchuKL44s6E&amp;t=50m28s">50:28</a> shouldn&#39;t it just say &quot;hl&quot;? You stop at the &quot;o&quot;?', 'comment_author_name': 'Cyrus Ehambaram', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJUKppcCep52AR3QFTzsEXiKPHxVbafXYBDL2WDiQA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,581 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,587 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,589 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,590 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugyn4KXaTHir2guqPOB4AaABAg', 'comment_text': 'great video!', 'comment_author_name': 'Mel BBB', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVOKVLbamFR9X7msT7cOnzkyV5KcM_KrjSeGxcU=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,593 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,598 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,601 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,603 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgztpmJQ-YqQ-L57VUR4AaABAg', 'comment_text': 'Interesting. I always thought it&#39;s called Phyton and not Python', 'comment_author_name': 'Jon Anon', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXg5AYyLYMaJRw2uGGgGYw3EKSeYnywuRJSOA=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,608 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,614 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,616 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,619 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgxCTPn6rUNvs8REEyt4AaABAg', 'comment_text': '3 years later and it&#39;s one of the best Python videos i have came across', 'comment_author_name': 'Ajay', 'comment_author_thumbnail': 'https://yt3.ggpht.com/4KrtYQYuBnQGT7Nc0PgQfzxr988W34_FNFPICWPPUX6DQTHw6p0cjdiG2BmYq-kttWqw3VW9Cw=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,624 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,632 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,634 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgzFH1brGbT9ehP3aOd4AaABAg', 'comment_text': 'You nailed it!', 'comment_author_name': 'Mohammad Abrar', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJU5deMrCdtR2v87zGdD_VfFoaU-ftVlYfPU7oCCsKgZpj5QK8MQw6PEseAgoZxU=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,638 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,646 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,648 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugzq0sZk0ytLd5Autct4AaABAg', 'comment_text': 'thank you, Micke, I have learned a lot, I did try the python documentation but very hard to follow and understand. many thanks, Bahram from the UK', 'comment_author_name': 'bahram mashafi', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXgwSR8ZX5cYkCduLNFt4nmfgAHnocCrtxiTM4EbhaIwTTuTzFfHlC4_la29AAe=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,653 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,659 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,661 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,663 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgybSgiJjiTghKm3MKx4AaABAg', 'comment_text': 'This is some high tier content.', 'comment_author_name': 'Snazzy Peanut', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJVCmFYMXRPGqZVQ1WLC88WOsYsB1KV9nhbXHyrX=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,665 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,673 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,674 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgzlwOgPiXFDhY1dtCV4AaABAg', 'comment_text': 'This video is the optimal summary thanks', 'comment_author_name': 'BAHI Brahim', 'comment_author_thumbnail': 'https://yt3.ggpht.com/6LLxq45q8GlA_UIpv5VllRj-byishUjPJqzDMIxBOzLWEB6I4z7EYTeH52QcWC1vKp8qpE0XcQ=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,676 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,682 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,683 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,684 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'Ugy5VFYIA3WvOOOL-pt4AaABAg', 'comment_text': 'Your examples are very well thought out, they often show 2 or 3 potential outcomes of various problems at the same time. I love how you construct scenarios that show us how the code reacts in a variety of ways. <br>Thanks for your thoughtful lesson design', 'comment_author_name': 'Benjamin Davis', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXnvgk4lxWVwrTHs74cNJBKi1x65WttfxE_=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,687 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,692 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,693 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,694 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgyqiS1kCwUGpqtHuax4AaABAg', 'comment_text': 'In school (US) we learned PEMDAS rather than BEDMAS. It&#39;s concerning that multiplication and divsion are flipped..', 'comment_author_name': 'Benjamin Davis', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJXnvgk4lxWVwrTHs74cNJBKi1x65WttfxE_=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,697 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-04 17:34:00,702 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-04 17:34:00,704 INFO sqlalchemy.engine.Engine INSERT INTO youtube_comment (comment_id, comment_text, comment_author_name, comment_author_thumbnail, video_id) VALUES (%(comment_id)s, %(comment_text)s, %(comment_author_name)s, %(comment_author_thumbnail)s, %(video_id)s)
# 2023-04-04 17:34:00,705 INFO sqlalchemy.engine.Engine [cached since 2012s ago] {'comment_id': 'UgzvPynyvii4UDjTCOx4AaABAg', 'comment_text': 'This was quite helpful', 'comment_author_name': 'Diário de um desenvolvedor', 'comment_author_thumbnail': 'https://yt3.ggpht.com/ytc/AL5GRJW-wLzfe9iLfyqC4Zvxh0mPTypwCYY_EsqR-ORuTg=s48-c-k-c0x00ffffff-no-rj', 'video_id': 'VchuKL44s6E'}
# 2023-04-04 17:34:00,708 INFO sqlalchemy.engine.Engine COMMIT

# %%
class YouTubeVideoCollection:
    def __init__(self):
        self.__youtube_videos = []
        self.__es_client = None
        
    def get_youtube_videos(self):
        return self.__youtube_videos
    
    def add_video(self, video: YouTubeVideo):
        self.__youtube_videos.append(video)
        
    def add_videos(self, videos: list[YouTubeVideo]):
        for video in videos:
            self.__youtube_videos.append(video)
    
    def save_to_database(self):
        pass
    
    def save_to_elasticsearch(self, index_name, elastic_search_host):
        if not self.__es_client:
            self.__create_es_client(elastic_search_host)
        for video in self.__youtube_videos:
            video_details = video.to_dict()
            self.__es_client.index(index=index_name, document=video_details, id=video_details['video_id'])
        
    def __delete_index(self, index_name):
        self.__es_client.indices.delete(index=index_name, ignore=[400, 404])
        
    def __create_index(self, index_name):
        self.__es_client.indices.create(index = index_name)
    
    def __create_es_client(self, es_host):
        if not self.__es_client:
            self.__es_client = Elasticsearch(hosts=[es_host])
    
    def save_to_csv(self):
        pass
    
    def save_to_json(self, file=''):
        if not file:
            file = 'file.json'
        with open(file, 'w') as file_path:
            videos = [video.to_dict() for video in self.__youtube_videos]
            json.dump(videos)
    
    def to_pandas(self):
        videos = [video.to_dict() for video in self.__youtube_videos]
        video_ids = []
        video_titles = []
        video_descriptions = []
        video_thumbnails = []
        video_tags = []
        channel_ids = []
        channel_titles = []
        for video in videos:
            video_ids.append(video['video_id'])
            video_titles.append(video['video_title'])
            video_descriptions.append(video['video_description'])
            video_thumbnails.append(video['video_thumbnail'])
            video_tags.append(video['video_tags'])
            channel_ids.append(video['channel_id'])
            channel_titles.append(video['channel_title'])
        data = {
            'video_id': video_ids,
            'video_title': video_titles,
            'video_description': video_descriptions,
            'video_thumbnail': video_thumbnails,
            'video_tags': video_tags,
            'channel_id': channel_ids,
            'channel_title': channel_titles
        }

        df = pd.DataFrame(data)

# %%
videos[0]
