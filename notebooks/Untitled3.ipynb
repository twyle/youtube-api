# %%
from stackapi import StackAPI

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 290,
#  'total': 0,
#  'items': [{'owner': {'reputation': 400863,
#     'user_id': 182668,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://www.gravatar.com/avatar/b19917aa04a6839aef577f1117c71d48?s=256&d=identicon&r=PG',
#     'display_name': 'Pointy',
#     'link': 'https://stackoverflow.com/users/182668/pointy'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1680134875,
#    'post_id': 75883110,
#    'comment_id': 133848214,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 487,
#     'user_id': 16220410,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/szkPI.png?s=256&g=1',
#     'display_name': 'k1dr0ck',
#     'link': 'https://stackoverflow.com/users/16220410/k1dr0ck'},
#    'reply_to_user': {'reputation': 148614,
#     'user_id': 478884,
#     'user_type': 'registered',
# ...
